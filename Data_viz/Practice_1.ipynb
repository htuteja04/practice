# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ucl_att = pd.read_csv('Datasets/UCL/attacking.csv', index_col=0)

# %%
ucl_att
# Out:
#              player_name              club    position  assists  corner_taken  \
# serial
# 1        Bruno Fernandes       Man. United  Midfielder        7            10
# 2        Vinícius Júnior       Real Madrid     Forward        6             3
# 2                   Sané            Bayern  Midfielder        6             3
# 4                 Antony              Ajax     Forward        5             3
# 5       Alexander-Arnold         Liverpool    Defender        4            36
# ...                  ...               ...         ...      ...           ...
# 64               Tolisso            Bayern  Midfielder        1             0
# 64               Schuurs              Ajax    Defender        1             0
# 64              Kryvtsov  Shakhtar Donetsk    Defender        1             0
# 64              Stanišić            Bayern    Defender        1             0
# 64              Bernardo          Salzburg    Defender        1             0
#
# ...

# %%
ucl_def = pd.read_csv('Datasets/UCL/defending.csv',index_col=0)

# %%
ucl_def
# Out:
#          player_name         club    position  balls_recoverd  tackles  t_won  \
# serial
# 1           Casemiro  Real Madrid  Midfielder              76       31     13
# 1       Éder Militão  Real Madrid    Defender              76       19      6
# 1           Reinildo     Atlético    Defender              76       13      6
# 4            Fabinho    Liverpool  Midfielder              74       23      9
# 5             Albiol   Villarreal    Defender              73        9      6
# ...              ...          ...         ...             ...      ...    ...
# 578            Maier   Young Boys  Midfielder               1        0      0
# 578         Zhegrova         LOSC  Midfielder               1        0      0
# 578          Zesiger   Young Boys    Defender               1        0      0
# 578          Zakaria     Juventus  Midfielder               1        0      0
# 578          Edwards  Sporting CP     Forward               1        0      0
#
# ...

# %%
plt.figure(figsize=(10.5, 5))
sns.barplot(x=ucl_def['player_name'][:10], y=ucl_def['tackles'][:10]);

# %%
key = pd.read_csv('Datasets/UCL/key_stats.csv')
key
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 742         Gil Dias      Benfica  Midfielder               1             1
# 743  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 744         Cojocari      Sheriff    Defender               1             1
# 745         Maouassa  Club Brugge    Defender               1             1
# 746          Zesiger   Young Boys    Defender               1             1
#
#      goals  assists distance_covered
# ...

# %%
gls = pd.read_csv('Datasets/UCL/goals.csv')

# %%
gls
# Out:
#      serial     player_name         club    position  goals  right_foot  \
# 0         1         Benzema  Real Madrid     Forward     15          11
# 1         2     Lewandowski       Bayern     Forward     13           8
# 2         3          Haller         Ajax     Forward     11           3
# 3         4           Salah    Liverpool     Forward      8           0
# 4         5          Nkunku      Leipzig  Midfielder      7           3
# ..      ...             ...          ...         ...    ...         ...
# 178      73         Yansané      Sheriff     Forward      1           0
# 179      73     Yakhshiboev      Sheriff     Forward      1           0
# 180      73  Messias Junior        Milan     Forward      1           0
# 181      73          Morato      Benfica    Defender      1           0
# 182      73     Pedro Porro  Sporting CP    Defender      1           0
#
#      left_foot  headers  others  inside_area  outside_areas  penalties  \
# ...

# %%
candy = pd.read_csv('Datasets/Viz/candy.csv')

# %%
candy
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
flight = pd.read_csv('Datasets/Viz/flight_delays.csv',index_col='Month')

# %%
flight
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
mean_US = flight['US'].mean()

# %%
flight['US'].fillna(mean_US, inplace=True)

# %%
plt.figure(figsize=(18,10))
sns.heatmap(flight, annot=True);

# %%
plt.figure(figsize=(18,10))
sns.heatmap(flight, annot=True, linewidths=0.5);

# %%
plt.figure(figsize=(18,10))
sns.heatmap(flight, annot=True, cmap='crest');

# %%
ign = pd.read_csv('Datasets/Viz/ign_scores.csv', index_col='Platform')
ign
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(ign, annot=True);

# %% [markdown]
# making the same heat map using Tableau

# %% [markdown]
# ![Heat%20map.png](attachment:Heat%20map.png)

# %%
ins = pd.read_csv('Datasets/Viz/insurance.csv')

# %%
ins
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x=ins['bmi'], y=ins['charges']);

# %%
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
sns.regplot(x=ins['bmi'], y=ins['charges']);

# %% [markdown]
# making same plots using Tableau

# %% [markdown]
# ![Scatter_plots.png](attachment:Scatter_plots.png)

# %%
ucl_att
# Out:
#              player_name              club    position  assists  corner_taken  \
# serial
# 1        Bruno Fernandes       Man. United  Midfielder        7            10
# 2        Vinícius Júnior       Real Madrid     Forward        6             3
# 2                   Sané            Bayern  Midfielder        6             3
# 4                 Antony              Ajax     Forward        5             3
# 5       Alexander-Arnold         Liverpool    Defender        4            36
# ...                  ...               ...         ...      ...           ...
# 64               Tolisso            Bayern  Midfielder        1             0
# 64               Schuurs              Ajax    Defender        1             0
# 64              Kryvtsov  Shakhtar Donetsk    Defender        1             0
# 64              Stanišić            Bayern    Defender        1             0
# 64              Bernardo          Salzburg    Defender        1             0
#
# ...

# %%
plt.figure(figsize=(14,8))
sns.barplot(x=ucl_att['player_name'][:10], y=ucl_att['assists'][:10]);

# %% [markdown]
# making the same bar plot using Tableau

# %% [markdown]
# ![bar_graph.png](attachment:bar_graph.png)

# %%
candy = pd.read_csv('Datasets/Viz/candy.csv', index_col='id')
candy
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
sns.scatterplot(x=candy.pricepercent, y=candy.winpercent, hue=candy.chocolate);

# %%
sns.scatterplot(x=candy.sugarpercent, y=candy.winpercent, hue=candy.chocolate);

# %%
sns.scatterplot(x=candy.pricepercent, y=candy.winpercent, hue=candy.caramel);

# %% [markdown]
# No significant correlation between winpercent & sugar-content/price

# %% [markdown]
# Making the same charts in Tableau

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x=candy.sugarpercent, y=candy.winpercent)
plt.title('Sugar correlation');

# %% [markdown]
# ![Scatterplot_2.png](attachment:Scatterplot_2.png)

# %%
iris = pd.read_csv('Datasets/Viz/iris.csv', index_col='Id')
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.histplot(data=iris, x='Petal Length (cm)', hue="Species");

# %%
sns.kdeplot(data=iris, x="Petal Length (cm)", hue="Species", shade=True);

# %%
candy
# Out:
#                 competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0                    100 Grand       Yes     No     Yes             No     No
# 1                 3 Musketeers       Yes     No      No             No    Yes
# 2                    Air Heads        No    Yes      No             No     No
# 3                   Almond Joy       Yes     No      No            Yes     No
# 4                    Baby Ruth       Yes     No     Yes            Yes    Yes
# ..                         ...       ...    ...     ...            ...    ...
# 78                   Twizzlers        No    Yes      No             No     No
# 79                    Warheads        No    Yes      No             No     No
# 80        Welch's Fruit Snacks        No    Yes      No             No     No
# 81  Werther's Original Caramel        No     No     Yes             No     No
# 82                    Whoppers       Yes     No      No             No     No
#
# ...

# %%
candy['sugarpercent'].corr(candy['winpercent'])
# Out:
# 0.20763497996748545

# %%
candy['winpercent'].corr(candy['sugarpercent'])
# Out:
# 0.20763497996748548

# %% [markdown]
# ![Plot_types.png](attachment:Plot_types.png)

# %%
sns.set_style('darkgrid')
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
sns.set_style('ticks')
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
sns.set_style('whitegrid')
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
sns.set_style('dark')
sns.scatterplot(x=ins['bmi'], y=ins['charges'], hue=ins['smoker']);

# %%
airs = pd.read_csv('../../538Datasets/data/airline-safety/airline-safety/airline-safety.csv')

# %%
airs
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
fatal_10 = airs[['airline','fatalities_85_99', 'fatalities_00_14']].sort_values(by='fatalities_00_14', ascending=False)[:10]

# %%
fatal_10
# Out:
#                   airline  fatalities_85_99  fatalities_00_14
# 34      Malaysia Airlines                34               537
# 11              American*               101               416
# 5              Air France                79               337
# 29          Kenya Airways                 0               283
# 16         China Airlines               535               225
# 47                    TAM                98               188
# 6              Air India*               329               158
# 25               Gulf Air                 0               143
# 39                   SAS*                 0               110
# 51  United / Continental*               319               109

# %%
safest_10 = airs[['airline', 'fatal_accidents_00_14']].sort_values(by='fatal_accidents_00_14')[:10]

# %%
safest_10
# Out:
#               airline  fatal_accidents_00_14
# 0          Aer Lingus                      0
# 26  Hawaiian Airlines                      0
# 54    Virgin Atlantic                      0
# 28     Japan Airlines                      0
# 30               KLM*                      0
# 31         Korean Air                      0
# 32       LAN Airlines                      0
# 33         Lufthansa*                      0
# 23            Finnair                      0
# 37            Qantas*                      0

# %%
comps = pd.read_json('data/competitions.json')
comps.head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None     2021-07-09T14:06:05.802
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
comps[comps['competition_name'] == 'Champions League']
# Out:
#     competition_id  season_id country_name  competition_name  \
# 0               16          4       Europe  Champions League
# 1               16          1       Europe  Champions League
# 2               16          2       Europe  Champions League
# 3               16         27       Europe  Champions League
# 4               16         26       Europe  Champions League
# 5               16         25       Europe  Champions League
# 6               16         24       Europe  Champions League
# 7               16         23       Europe  Champions League
# 8               16         22       Europe  Champions League
# 9               16         21       Europe  Champions League
# 10              16         41       Europe  Champions League
# 11              16         39       Europe  Champions League
# 12              16         37       Europe  Champions League
# 13              16         44       Europe  Champions League
# 14              16         76       Europe  Champions League
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                      False
# 3                male              False                      False
# 4                male              False                      False
# 5                male              False                      False
# 6                male              False                      False
# 7                male              False                      False
# 8                male              False                      False
# 9                male              False                      False
# 10               male              False                      False
# 11               male              False                      False
# 12               male              False                      False
# 13               male              False                      False
# 14               male              False                      False
#
#    season_name               match_updated        match_updated_360  \
# 0    2018/2019  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 1    2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2    2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3    2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4    2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 5    2013/2014  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 6    2012/2013  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 7    2011/2012  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 8    2010/2011  2022-01-26T21:07:11.033473  2021-06-13T16:17:31.694
# 9    2009/2010  2022-02-12T16:13:49.294747  2021-06-13T16:17:31.694
# 10   2008/2009  2021-11-07T14:20:01.699993  2021-06-13T16:17:31.694
# 11   2006/2007  2021-03-31T04:18:30.437060  2021-06-13T16:17:31.694
# 12   2004/2005  2021-04-01T06:18:57.459032  2021-06-13T16:17:31.694
# 13   2003/2004  2021-04-01T00:34:59.472485  2021-06-13T16:17:31.694
# 14   1999/2000            2020-07-29T05:00  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 0                 None     2021-07-09T14:06:05.802
# 1                 None  2021-01-23T21:55:30.425330
# 2                 None            2020-07-29T05:00
# 3                 None            2020-07-29T05:00
# 4                 None            2020-07-29T05:00
# 5                 None            2020-07-29T05:00
# 6                 None     2021-07-10T13:41:45.751
# 7                 None            2020-07-29T05:00
# 8                 None  2022-01-26T21:07:11.033473
# 9                 None  2022-02-12T16:13:49.294747
# 10                None  2021-11-07T14:20:01.699993
# 11                None  2021-03-31T04:18:30.437060
# 12                None  2021-04-01T06:18:57.459032
# 13                None  2021-04-01T00:34:59.472485
# 14                None            2020-07-29T05:00

# %%
import json

with open('data/matches/16/24.json') as f:
    data = json.load(f)
    for i in data:
        print('ID:', i['match_id'], i['home_team']['home_team_name'], i['home_score'], '-', i['away_score'], i['away_team']['away_team_name'])
# Out:
# ID: 18240 Borussia Dortmund 1 - 2 Bayern Munich

# %%
with open('data/events/18240.json', encoding="utf8") as f:
    derklassiker = json.load(f)
    
derklassiker
# Out:
# [{'id': 'b31524cb-9a15-4386-9954-f61a93fbb9a2',
#   'index': 1,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'duration': 0.0,
#   'tactics': {'formation': 4231,
#    'lineup': [{'player': {'id': 12424, 'name': 'Roman Weidenfeller'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 1},
#     {'player': {'id': 5658, 'name': 'Łukasz Piszczek'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 26},
#     {'player': {'id': 4430, 'name': 'Neven Subotić'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 4},
#     {'player': {'id': 5572, 'name': 'Mats Hummels'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 15},
#     {'player': {'id': 11458, 'name': 'Marcel Schmelzer'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 29},
#     {'player': {'id': 8216, 'name': 'Sven Bender'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'jersey_number': 6},
#     {'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'jersey_number': 8},
#     {'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'jersey_number': 16},
#     {'player': {'id': 5559, 'name': 'Marco Reus'},
#      'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#      'jersey_number': 11},
#     {'player': {'id': 20665, 'name': 'Kevin Großkreutz'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'jersey_number': 19},
#     {'player': {'id': 5668, 'name': 'Robert Lewandowski'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 9}]}},
#  {'id': '1b365f44-4d6c-4f60-955d-eb2990a2b0fd',
#   'index': 2,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 35, 'name': 'Starting XI'},
#   'possession': 1,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'duration': 0.0,
#   'tactics': {'formation': 4231,
#    'lineup': [{'player': {'id': 5570, 'name': 'Manuel Neuer'},
#      'position': {'id': 1, 'name': 'Goalkeeper'},
#      'jersey_number': 1},
#     {'player': {'id': 19295, 'name': 'Philipp Lahm'},
#      'position': {'id': 2, 'name': 'Right Back'},
#      'jersey_number': 21},
#     {'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#      'position': {'id': 3, 'name': 'Right Center Back'},
#      'jersey_number': 17},
#     {'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#      'position': {'id': 5, 'name': 'Left Center Back'},
#      'jersey_number': 4},
#     {'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#      'position': {'id': 6, 'name': 'Left Back'},
#      'jersey_number': 27},
#     {'player': {'id': 9399, 'name': 'Javier Martínez Aginaga'},
#      'position': {'id': 9, 'name': 'Right Defensive Midfield'},
#      'jersey_number': 8},
#     {'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#      'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#      'jersey_number': 31},
#     {'player': {'id': 8218, 'name': 'Arjen Robben'},
#      'position': {'id': 17, 'name': 'Right Wing'},
#      'jersey_number': 10},
#     {'player': {'id': 5562, 'name': 'Thomas Müller'},
#      'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#      'jersey_number': 25},
#     {'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#      'position': {'id': 21, 'name': 'Left Wing'},
#      'jersey_number': 7},
#     {'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#      'position': {'id': 23, 'name': 'Center Forward'},
#      'jersey_number': 9}]}},
#  {'id': 'c60553e8-e8a8-4bd4-9e45-9c74dab0bca1',
#   'index': 3,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'duration': 0.0,
#   'related_events': ['15090649-ebc5-4c08-b54f-719107b67abf']},
#  {'id': '15090649-ebc5-4c08-b54f-719107b67abf',
#   'index': 4,
#   'period': 1,
#   'timestamp': '00:00:00.000',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 18, 'name': 'Half Start'},
#   'possession': 1,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'duration': 0.0,
#   'related_events': ['c60553e8-e8a8-4bd4-9e45-9c74dab0bca1']},
#  {'id': 'a2615e19-4e6e-46ce-bfe7-9687c5c6fd87',
#   'index': 5,
#   'period': 1,
#   'timestamp': '00:00:00.632',
#   'minute': 0,
#   'second': 0,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [60.0, 40.0],
#   'duration': 0.4,
#   'related_events': ['485d85af-3a34-4a88-a852-5c9827f432f0'],
#   'pass': {'recipient': {'id': 5562, 'name': 'Thomas Müller'},
#    'length': 3.6055512,
#    'angle': 0.98279375,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [62.0, 43.0],
#    'type': {'id': 65, 'name': 'Kick Off'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '485d85af-3a34-4a88-a852-5c9827f432f0',
#   'index': 6,
#   'period': 1,
#   'timestamp': '00:00:01.032',
#   'minute': 0,
#   'second': 1,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5562, 'name': 'Thomas Müller'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [62.0, 43.0],
#   'related_events': ['a2615e19-4e6e-46ce-bfe7-9687c5c6fd87']},
#  {'id': '9ccad95f-3cba-4674-805b-989d2c44c54a',
#   'index': 7,
#   'period': 1,
#   'timestamp': '00:00:01.032',
#   'minute': 0,
#   'second': 1,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5562, 'name': 'Thomas Müller'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [62.0, 43.0],
#   'duration': 0.040000003,
#   'related_events': ['485d85af-3a34-4a88-a852-5c9827f432f0',
#    'ac3fca2d-933d-4436-bf33-cc6f29e26193'],
#   'carry': {'end_location': [61.0, 43.0]}},
#  {'id': 'ac3fca2d-933d-4436-bf33-cc6f29e26193',
#   'index': 8,
#   'period': 1,
#   'timestamp': '00:00:01.072',
#   'minute': 0,
#   'second': 1,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5562, 'name': 'Thomas Müller'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [61.0, 43.0],
#   'duration': 1.230583,
#   'related_events': ['0c7dc55b-fa1b-4bbd-a87d-898b3a1eb9d4'],
#   'pass': {'recipient': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#    'length': 17.262676,
#    'angle': -2.9669204,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [44.0, 40.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '0c7dc55b-fa1b-4bbd-a87d-898b3a1eb9d4',
#   'index': 9,
#   'period': 1,
#   'timestamp': '00:00:02.302',
#   'minute': 0,
#   'second': 2,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [44.0, 40.0],
#   'related_events': ['ac3fca2d-933d-4436-bf33-cc6f29e26193']},
#  {'id': '64c5ba49-ef33-4032-b65e-79b9cc4639ed',
#   'index': 10,
#   'period': 1,
#   'timestamp': '00:00:02.302',
#   'minute': 0,
#   'second': 2,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [44.0, 40.0],
#   'duration': 1.064986,
#   'related_events': ['0c7dc55b-fa1b-4bbd-a87d-898b3a1eb9d4',
#    'cb62c659-2133-40ff-b176-77941d61ceb8'],
#   'carry': {'end_location': [43.0, 41.0]}},
#  {'id': 'cb62c659-2133-40ff-b176-77941d61ceb8',
#   'index': 11,
#   'period': 1,
#   'timestamp': '00:00:03.367',
#   'minute': 0,
#   'second': 3,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [43.0, 41.0],
#   'duration': 1.359776,
#   'related_events': ['3330eb10-237e-448c-99b0-3ec305050d80'],
#   'pass': {'recipient': {'id': 19295, 'name': 'Philipp Lahm'},
#    'length': 25.495098,
#    'angle': 1.3734008,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [48.0, 66.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '3330eb10-237e-448c-99b0-3ec305050d80',
#   'index': 12,
#   'period': 1,
#   'timestamp': '00:00:04.727',
#   'minute': 0,
#   'second': 4,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 19295, 'name': 'Philipp Lahm'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [48.0, 66.0],
#   'related_events': ['cb62c659-2133-40ff-b176-77941d61ceb8']},
#  {'id': '24c82be1-f607-42c2-9e17-73a1229816c9',
#   'index': 13,
#   'period': 1,
#   'timestamp': '00:00:04.727',
#   'minute': 0,
#   'second': 4,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 19295, 'name': 'Philipp Lahm'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [48.0, 66.0],
#   'duration': 1.822465,
#   'under_pressure': True,
#   'related_events': ['3330eb10-237e-448c-99b0-3ec305050d80',
#    '9ae2bf23-639c-4771-861d-8ecfcefed730',
#    'b455695e-8c4a-4230-a114-a53df59117f2'],
#   'carry': {'end_location': [48.0, 60.0]}},
#  {'id': '9ae2bf23-639c-4771-861d-8ecfcefed730',
#   'index': 14,
#   'period': 1,
#   'timestamp': '00:00:05.668',
#   'minute': 0,
#   'second': 5,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 20665, 'name': 'Kevin Großkreutz'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [71.0, 18.0],
#   'duration': 0.480959,
#   'related_events': ['24c82be1-f607-42c2-9e17-73a1229816c9']},
#  {'id': 'b455695e-8c4a-4230-a114-a53df59117f2',
#   'index': 15,
#   'period': 1,
#   'timestamp': '00:00:06.550',
#   'minute': 0,
#   'second': 6,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 19295, 'name': 'Philipp Lahm'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [48.0, 60.0],
#   'duration': 1.91638,
#   'related_events': ['df7ff689-b471-4d54-b68d-ed97e0c1c81d'],
#   'pass': {'recipient': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#    'length': 36.40055,
#    'angle': -2.219792,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [26.0, 31.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'df7ff689-b471-4d54-b68d-ed97e0c1c81d',
#   'index': 16,
#   'period': 1,
#   'timestamp': '00:00:08.466',
#   'minute': 0,
#   'second': 8,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [26.0, 31.0],
#   'related_events': ['b455695e-8c4a-4230-a114-a53df59117f2']},
#  {'id': '8ab43b38-a5c8-4a27-99e8-16b549addfb2',
#   'index': 17,
#   'period': 1,
#   'timestamp': '00:00:08.466',
#   'minute': 0,
#   'second': 8,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [26.0, 31.0],
#   'duration': 1.860225,
#   'related_events': ['9cab6908-1730-4b8b-b75b-1fcb9bb26d68',
#    'df7ff689-b471-4d54-b68d-ed97e0c1c81d'],
#   'carry': {'end_location': [24.0, 24.0]}},
#  {'id': '9cab6908-1730-4b8b-b75b-1fcb9bb26d68',
#   'index': 18,
#   'period': 1,
#   'timestamp': '00:00:10.326',
#   'minute': 0,
#   'second': 10,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [24.0, 24.0],
#   'duration': 1.290792,
#   'related_events': ['9cb64faa-407f-41d0-b98a-2e7ffb99758a'],
#   'pass': {'recipient': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#    'length': 20.808653,
#    'angle': -0.95613337,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [36.0, 7.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '9cb64faa-407f-41d0-b98a-2e7ffb99758a',
#   'index': 19,
#   'period': 1,
#   'timestamp': '00:00:11.617',
#   'minute': 0,
#   'second': 11,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [36.0, 7.0],
#   'related_events': ['9cab6908-1730-4b8b-b75b-1fcb9bb26d68']},
#  {'id': '5aa655d9-1a3e-4bf6-b17e-494286b44097',
#   'index': 20,
#   'period': 1,
#   'timestamp': '00:00:11.617',
#   'minute': 0,
#   'second': 11,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [36.0, 7.0],
#   'duration': 1.859895,
#   'related_events': ['6419d9bc-f55c-4a9d-bd39-9cb2110f3217',
#    '9cb64faa-407f-41d0-b98a-2e7ffb99758a'],
#   'carry': {'end_location': [34.0, 7.0]}},
#  {'id': '6419d9bc-f55c-4a9d-bd39-9cb2110f3217',
#   'index': 21,
#   'period': 1,
#   'timestamp': '00:00:13.477',
#   'minute': 0,
#   'second': 13,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [34.0, 7.0],
#   'duration': 1.099277,
#   'related_events': ['aa268b16-8d25-4b20-b91d-d2c020cec9b2'],
#   'pass': {'recipient': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#    'length': 10.630146,
#    'angle': 2.4227626,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [26.0, 14.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'aa268b16-8d25-4b20-b91d-d2c020cec9b2',
#   'index': 22,
#   'period': 1,
#   'timestamp': '00:00:14.576',
#   'minute': 0,
#   'second': 14,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [26.0, 14.0],
#   'related_events': ['6419d9bc-f55c-4a9d-bd39-9cb2110f3217']},
#  {'id': 'e4cf7b75-f212-47ed-99a0-e2e5b74991f1',
#   'index': 23,
#   'period': 1,
#   'timestamp': '00:00:14.576',
#   'minute': 0,
#   'second': 14,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [26.0, 14.0],
#   'duration': 2.895032,
#   'under_pressure': True,
#   'related_events': ['9d340dd2-211c-44bb-b3a6-d374b3768914',
#    'aa268b16-8d25-4b20-b91d-d2c020cec9b2',
#    'f26471f4-8f48-4c19-a66d-640c9442d776'],
#   'carry': {'end_location': [24.0, 17.0]}},
#  {'id': '9d340dd2-211c-44bb-b3a6-d374b3768914',
#   'index': 24,
#   'period': 1,
#   'timestamp': '00:00:17.126',
#   'minute': 0,
#   'second': 17,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5668, 'name': 'Robert Lewandowski'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [91.0, 67.0],
#   'duration': 0.491152,
#   'related_events': ['e4cf7b75-f212-47ed-99a0-e2e5b74991f1',
#    'f26471f4-8f48-4c19-a66d-640c9442d776']},
#  {'id': 'f26471f4-8f48-4c19-a66d-640c9442d776',
#   'index': 25,
#   'period': 1,
#   'timestamp': '00:00:17.471',
#   'minute': 0,
#   'second': 17,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [24.0, 17.0],
#   'duration': 1.555175,
#   'under_pressure': True,
#   'related_events': ['54dd230a-27e1-4765-b7cc-d4e40d514323',
#    '9d340dd2-211c-44bb-b3a6-d374b3768914'],
#   'pass': {'recipient': {'id': 5570, 'name': 'Manuel Neuer'},
#    'length': 20.248457,
#    'angle': 2.145101,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [13.0, 34.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '54dd230a-27e1-4765-b7cc-d4e40d514323',
#   'index': 26,
#   'period': 1,
#   'timestamp': '00:00:19.026',
#   'minute': 0,
#   'second': 19,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5570, 'name': 'Manuel Neuer'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [13.0, 34.0],
#   'related_events': ['f26471f4-8f48-4c19-a66d-640c9442d776']},
#  {'id': '66e5e888-aafd-4c43-b777-f3b15c8f5183',
#   'index': 27,
#   'period': 1,
#   'timestamp': '00:00:19.026',
#   'minute': 0,
#   'second': 19,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5570, 'name': 'Manuel Neuer'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [13.0, 34.0],
#   'duration': 2.591148,
#   'related_events': ['3ae0c699-5f12-44b8-8226-b67554d42f14',
#    '54dd230a-27e1-4765-b7cc-d4e40d514323'],
#   'carry': {'end_location': [14.0, 38.0]}},
#  {'id': '3ae0c699-5f12-44b8-8226-b67554d42f14',
#   'index': 28,
#   'period': 1,
#   'timestamp': '00:00:21.617',
#   'minute': 0,
#   'second': 21,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5570, 'name': 'Manuel Neuer'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [14.0, 38.0],
#   'duration': 1.877583,
#   'related_events': ['90c8b524-aa34-4584-9c60-7674b2881a9a'],
#   'pass': {'recipient': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#    'length': 18.248287,
#    'angle': -1.4056476,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [17.0, 20.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '90c8b524-aa34-4584-9c60-7674b2881a9a',
#   'index': 29,
#   'period': 1,
#   'timestamp': '00:00:23.495',
#   'minute': 0,
#   'second': 23,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [17.0, 20.0],
#   'related_events': ['3ae0c699-5f12-44b8-8226-b67554d42f14']},
#  {'id': '7b774f6b-f974-40bb-bf94-b8c7aa6b7f5c',
#   'index': 30,
#   'period': 1,
#   'timestamp': '00:00:23.495',
#   'minute': 0,
#   'second': 23,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [17.0, 20.0],
#   'duration': 3.093567,
#   'related_events': ['90c8b524-aa34-4584-9c60-7674b2881a9a',
#    'd7a94447-7266-4ec1-9655-6310d720562f'],
#   'carry': {'end_location': [22.0, 16.0]}},
#  {'id': 'd7a94447-7266-4ec1-9655-6310d720562f',
#   'index': 31,
#   'period': 1,
#   'timestamp': '00:00:26.589',
#   'minute': 0,
#   'second': 26,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [22.0, 16.0],
#   'duration': 0.997296,
#   'related_events': ['8dd79121-5dcd-4f71-9a4d-7891a17b3ed8'],
#   'pass': {'recipient': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#    'length': 18.248287,
#    'angle': 1.735945,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [19.0, 34.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '8dd79121-5dcd-4f71-9a4d-7891a17b3ed8',
#   'index': 32,
#   'period': 1,
#   'timestamp': '00:00:27.586',
#   'minute': 0,
#   'second': 27,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [19.0, 34.0],
#   'related_events': ['d7a94447-7266-4ec1-9655-6310d720562f']},
#  {'id': 'f5392252-3b84-462a-8492-07497c1d57db',
#   'index': 33,
#   'period': 1,
#   'timestamp': '00:00:27.586',
#   'minute': 0,
#   'second': 27,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [19.0, 34.0],
#   'duration': 4.397685,
#   'related_events': ['6a1f1ab5-aa41-46a3-9214-a5b4f26e96fa',
#    '8dd79121-5dcd-4f71-9a4d-7891a17b3ed8'],
#   'carry': {'end_location': [29.0, 40.0]}},
#  {'id': '6a1f1ab5-aa41-46a3-9214-a5b4f26e96fa',
#   'index': 34,
#   'period': 1,
#   'timestamp': '00:00:31.984',
#   'minute': 0,
#   'second': 31,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [29.0, 40.0],
#   'duration': 2.243884,
#   'related_events': ['84c16baa-a5d4-43e4-b692-960f38ee037c'],
#   'pass': {'recipient': {'id': 5578, 'name': 'Jérôme Boateng'},
#    'length': 32.75668,
#    'angle': 1.3554386,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [36.0, 72.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '84c16baa-a5d4-43e4-b692-960f38ee037c',
#   'index': 35,
#   'period': 1,
#   'timestamp': '00:00:34.227',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [36.0, 72.0],
#   'related_events': ['6a1f1ab5-aa41-46a3-9214-a5b4f26e96fa']},
#  {'id': '581a9f50-f3a6-44c8-b438-cfba984760e9',
#   'index': 36,
#   'period': 1,
#   'timestamp': '00:00:34.227',
#   'minute': 0,
#   'second': 34,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [36.0, 72.0],
#   'duration': 1.842316,
#   'related_events': ['1350e854-af5b-4f7f-8f4b-c3656db85d3d',
#    '84c16baa-a5d4-43e4-b692-960f38ee037c'],
#   'carry': {'end_location': [44.0, 73.0]}},
#  {'id': '1350e854-af5b-4f7f-8f4b-c3656db85d3d',
#   'index': 37,
#   'period': 1,
#   'timestamp': '00:00:36.070',
#   'minute': 0,
#   'second': 36,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [44.0, 73.0],
#   'duration': 2.441335,
#   'related_events': ['ed794d33-2ef0-4c18-90a6-76522c490b41',
#    'f51f961b-da67-481b-bb3a-ab0b6ef56645'],
#   'pass': {'recipient': {'id': 5562, 'name': 'Thomas Müller'},
#    'length': 53.75872,
#    'angle': -0.32175055,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [95.0, 56.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'},
#    'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'f51f961b-da67-481b-bb3a-ab0b6ef56645',
#   'index': 38,
#   'period': 1,
#   'timestamp': '00:00:38.511',
#   'minute': 0,
#   'second': 38,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5562, 'name': 'Thomas Müller'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [97.0, 53.0],
#   'related_events': ['1350e854-af5b-4f7f-8f4b-c3656db85d3d'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'ed794d33-2ef0-4c18-90a6-76522c490b41',
#   'index': 39,
#   'period': 1,
#   'timestamp': '00:00:38.511',
#   'minute': 0,
#   'second': 38,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 2,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 9, 'name': 'From Kick Off'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5572, 'name': 'Mats Hummels'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [26.0, 25.0],
#   'duration': 3.434915,
#   'related_events': ['1350e854-af5b-4f7f-8f4b-c3656db85d3d'],
#   'pass': {'length': 24.738634,
#    'angle': -1.815775,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [20.0, 1.0],
#    'outcome': {'id': 75, 'name': 'Out'},
#    'body_part': {'id': 37, 'name': 'Head'},
#    'type': {'id': 66, 'name': 'Recovery'}}},
#  {'id': 'eeba2c4e-08f8-469c-852a-9ba327ad77c9',
#   'index': 40,
#   'period': 1,
#   'timestamp': '00:00:44.079',
#   'minute': 0,
#   'second': 44,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 3,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [102.0, 80.0],
#   'duration': 3.242167,
#   'related_events': ['4ea2abcc-6032-4ce8-8fe5-286315254bed',
#    'bd81e48a-d677-4849-944a-783e4ed34528'],
#   'pass': {'recipient': {'id': 5562, 'name': 'Thomas Müller'},
#    'length': 34.43835,
#    'angle': -1.120135,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [117.0, 49.0],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'type': {'id': 67, 'name': 'Throw-in'}}},
#  {'id': '441400f0-96ef-4620-8f2d-c41f65c05309',
#   'index': 41,
#   'period': 1,
#   'timestamp': '00:00:46.088',
#   'minute': 0,
#   'second': 46,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 3,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 4430, 'name': 'Neven Subotić'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [8.0, 27.0],
#   'duration': 0.795361},
#  {'id': '4ea2abcc-6032-4ce8-8fe5-286315254bed',
#   'index': 42,
#   'period': 1,
#   'timestamp': '00:00:47.322',
#   'minute': 0,
#   'second': 47,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 3,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 4, 'name': 'From Throw In'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5562, 'name': 'Thomas Müller'},
#   'position': {'id': 19, 'name': 'Center Attacking Midfield'},
#   'location': [115.0, 54.0],
#   'related_events': ['eeba2c4e-08f8-469c-852a-9ba327ad77c9'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': 'bd81e48a-d677-4849-944a-783e4ed34528',
#   'index': 43,
#   'period': 1,
#   'timestamp': '00:00:47.322',
#   'minute': 0,
#   'second': 47,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 12424, 'name': 'Roman Weidenfeller'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [4.0, 32.0],
#   'duration': 0.0,
#   'related_events': ['eeba2c4e-08f8-469c-852a-9ba327ad77c9']},
#  {'id': 'ebbb3c73-aa65-4edc-9df3-158c5e45cfa5',
#   'index': 44,
#   'period': 1,
#   'timestamp': '00:00:47.322',
#   'minute': 0,
#   'second': 47,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 12424, 'name': 'Roman Weidenfeller'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [4.0, 32.0],
#   'duration': 11.858,
#   'related_events': ['6906ebf8-bc91-429c-851f-cc9f55345e2a',
#    'bd81e48a-d677-4849-944a-783e4ed34528'],
#   'carry': {'end_location': [5.0, 32.0]}},
#  {'id': '6906ebf8-bc91-429c-851f-cc9f55345e2a',
#   'index': 45,
#   'period': 1,
#   'timestamp': '00:00:59.180',
#   'minute': 0,
#   'second': 59,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 12424, 'name': 'Roman Weidenfeller'},
#   'position': {'id': 1, 'name': 'Goalkeeper'},
#   'location': [5.0, 32.0],
#   'duration': 2.933564,
#   'related_events': ['729c9af4-828c-47ba-a74c-9edcc273f505',
#    'bc860fd3-3f72-4037-8b3e-c7101bf51265'],
#   'pass': {'recipient': {'id': 5668, 'name': 'Robert Lewandowski'},
#    'length': 79.00633,
#    'angle': 0.012657552,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [84.0, 33.0],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 68, 'name': 'Drop Kick'}}},
#  {'id': 'bc860fd3-3f72-4037-8b3e-c7101bf51265',
#   'index': 46,
#   'period': 1,
#   'timestamp': '00:01:02.113',
#   'minute': 1,
#   'second': 2,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5668, 'name': 'Robert Lewandowski'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [83.0, 33.0],
#   'related_events': ['6906ebf8-bc91-429c-851f-cc9f55345e2a'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '729c9af4-828c-47ba-a74c-9edcc273f505',
#   'index': 47,
#   'period': 1,
#   'timestamp': '00:01:02.113',
#   'minute': 1,
#   'second': 2,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 3197, 'name': 'Dante Bonfim da Costa Santos'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [37.0, 48.0],
#   'duration': 1.782836,
#   'related_events': ['3d03ef22-feae-40b8-ad34-16771a256fb8',
#    '6906ebf8-bc91-429c-851f-cc9f55345e2a'],
#   'pass': {'length': 25.96151,
#    'angle': -1.2977877,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [44.0, 23.0],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'type': {'id': 66, 'name': 'Recovery'},
#    'body_part': {'id': 37, 'name': 'Head'}}},
#  {'id': '3d03ef22-feae-40b8-ad34-16771a256fb8',
#   'index': 48,
#   'period': 1,
#   'timestamp': '00:01:03.896',
#   'minute': 1,
#   'second': 3,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [77.0, 58.0],
#   'duration': 0.0,
#   'related_events': ['729c9af4-828c-47ba-a74c-9edcc273f505']},
#  {'id': '2afd9cce-40e8-46ac-8594-be78853409ad',
#   'index': 49,
#   'period': 1,
#   'timestamp': '00:01:03.896',
#   'minute': 1,
#   'second': 3,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [77.0, 58.0],
#   'duration': 2.55698,
#   'under_pressure': True,
#   'related_events': ['3d03ef22-feae-40b8-ad34-16771a256fb8',
#    'e7576782-f20e-4899-8618-d399d2e4a3d0',
#    'f3530e79-e39a-4f79-9c06-73b3ba9158a4'],
#   'carry': {'end_location': [92.0, 56.0]}},
#  {'id': 'e7576782-f20e-4899-8618-d399d2e4a3d0',
#   'index': 50,
#   'period': 1,
#   'timestamp': '00:01:04.997',
#   'minute': 1,
#   'second': 4,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [35.0, 23.0],
#   'duration': 0.714088,
#   'related_events': ['2afd9cce-40e8-46ac-8594-be78853409ad']},
#  {'id': 'f3530e79-e39a-4f79-9c06-73b3ba9158a4',
#   'index': 51,
#   'period': 1,
#   'timestamp': '00:01:06.453',
#   'minute': 1,
#   'second': 6,
#   'type': {'id': 3, 'name': 'Dispossessed'},
#   'possession': 4,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [92.0, 56.0],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['362beea9-9412-4479-98a0-595ee693ecef']},
#  {'id': '362beea9-9412-4479-98a0-595ee693ecef',
#   'index': 52,
#   'period': 1,
#   'timestamp': '00:01:06.453',
#   'minute': 1,
#   'second': 6,
#   'type': {'id': 4, 'name': 'Duel'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [29.0, 25.0],
#   'duration': 0.0,
#   'under_pressure': True,
#   'counterpress': True,
#   'related_events': ['f3530e79-e39a-4f79-9c06-73b3ba9158a4'],
#   'duel': {'outcome': {'id': 16, 'name': 'Success In Play'},
#    'type': {'id': 11, 'name': 'Tackle'}}},
#  {'id': 'f3fa82ea-7d6e-403a-aac4-624fc364cb73',
#   'index': 53,
#   'period': 1,
#   'timestamp': '00:01:08.233',
#   'minute': 1,
#   'second': 8,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [109.0, 57.0],
#   'duration': 0.344505,
#   'counterpress': True,
#   'related_events': ['0d9c6d9e-bacf-4215-9b0d-0b67e36410ed',
#    'e58a4354-864d-4009-aa7a-ab7df8ad2d8f']},
#  {'id': '0d9c6d9e-bacf-4215-9b0d-0b67e36410ed',
#   'index': 54,
#   'period': 1,
#   'timestamp': '00:01:08.464',
#   'minute': 1,
#   'second': 8,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [7.0, 24.0],
#   'duration': 0.0,
#   'under_pressure': True,
#   'related_events': ['f3fa82ea-7d6e-403a-aac4-624fc364cb73']},
#  {'id': 'e58a4354-864d-4009-aa7a-ab7df8ad2d8f',
#   'index': 55,
#   'period': 1,
#   'timestamp': '00:01:08.464',
#   'minute': 1,
#   'second': 8,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [7.0, 24.0],
#   'duration': 0.93537,
#   'under_pressure': True,
#   'related_events': ['0d9c6d9e-bacf-4215-9b0d-0b67e36410ed',
#    '4e58a8f5-0aee-4827-a3e2-de1db28204da',
#    'f3fa82ea-7d6e-403a-aac4-624fc364cb73'],
#   'carry': {'end_location': [7.0, 21.0]}},
#  {'id': '4e58a8f5-0aee-4827-a3e2-de1db28204da',
#   'index': 56,
#   'period': 1,
#   'timestamp': '00:01:09.400',
#   'minute': 1,
#   'second': 9,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8220, 'name': 'David Olatukunbo Alaba'},
#   'position': {'id': 6, 'name': 'Left Back'},
#   'location': [7.0, 21.0],
#   'duration': 1.652523,
#   'related_events': ['135dae3d-6763-4bea-b77b-15c107e27124'],
#   'pass': {'recipient': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#    'length': 14.21267,
#    'angle': -0.6857295,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [18.0, 12.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': '135dae3d-6763-4bea-b77b-15c107e27124',
#   'index': 57,
#   'period': 1,
#   'timestamp': '00:01:11.052',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [18.0, 12.0],
#   'related_events': ['4e58a8f5-0aee-4827-a3e2-de1db28204da']},
#  {'id': '0a465232-2801-46cc-b38b-17faef5b9178',
#   'index': 58,
#   'period': 1,
#   'timestamp': '00:01:11.052',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [18.0, 12.0],
#   'duration': 0.636803,
#   'related_events': ['135dae3d-6763-4bea-b77b-15c107e27124',
#    '73151912-fbf9-4a2f-921b-ffdc7e1a4c07'],
#   'carry': {'end_location': [19.0, 11.0]}},
#  {'id': '73151912-fbf9-4a2f-921b-ffdc7e1a4c07',
#   'index': 59,
#   'period': 1,
#   'timestamp': '00:01:11.689',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [19.0, 11.0],
#   'duration': 1.284285,
#   'related_events': ['f2f7cd7b-93cb-4e90-80e8-153e39414e5b'],
#   'pass': {'recipient': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#    'length': 11.18034,
#    'angle': 0.4636476,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [29.0, 16.0],
#    'body_part': {'id': 38, 'name': 'Left Foot'}}},
#  {'id': 'e864f594-7c5b-4f6b-964f-0fbd041bf9a3',
#   'index': 60,
#   'period': 1,
#   'timestamp': '00:01:11.733',
#   'minute': 1,
#   'second': 11,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5658, 'name': 'Łukasz Piszczek'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [95.0, 69.0],
#   'duration': 0.635581},
#  {'id': 'f2f7cd7b-93cb-4e90-80e8-153e39414e5b',
#   'index': 61,
#   'period': 1,
#   'timestamp': '00:01:12.973',
#   'minute': 1,
#   'second': 12,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [29.0, 16.0],
#   'related_events': ['73151912-fbf9-4a2f-921b-ffdc7e1a4c07']},
#  {'id': 'aca91760-fc7c-4015-a41b-b72329a03cc8',
#   'index': 62,
#   'period': 1,
#   'timestamp': '00:01:12.973',
#   'minute': 1,
#   'second': 12,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [29.0, 16.0],
#   'duration': 0.040018,
#   'related_events': ['f2f7cd7b-93cb-4e90-80e8-153e39414e5b',
#    'ffdb13bb-7813-4bd1-a52a-18c5ab501796'],
#   'carry': {'end_location': [26.0, 17.0]}},
#  {'id': 'ffdb13bb-7813-4bd1-a52a-18c5ab501796',
#   'index': 63,
#   'period': 1,
#   'timestamp': '00:01:13.013',
#   'minute': 1,
#   'second': 13,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 18414, 'name': 'Bastian Schweinsteiger'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [26.0, 17.0],
#   'duration': 1.172625,
#   'related_events': ['ecbc64b9-702e-42d4-95fa-5c03e18b24bd'],
#   'pass': {'recipient': {'id': 5578, 'name': 'Jérôme Boateng'},
#    'length': 23.259407,
#    'angle': 2.0152156,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [16.0, 38.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'ecbc64b9-702e-42d4-95fa-5c03e18b24bd',
#   'index': 64,
#   'period': 1,
#   'timestamp': '00:01:14.186',
#   'minute': 1,
#   'second': 14,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [16.0, 38.0],
#   'related_events': ['ffdb13bb-7813-4bd1-a52a-18c5ab501796']},
#  {'id': 'e7522506-94c5-4e18-bfe5-29297204b889',
#   'index': 65,
#   'period': 1,
#   'timestamp': '00:01:14.186',
#   'minute': 1,
#   'second': 14,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [16.0, 38.0],
#   'duration': 2.196299,
#   'related_events': ['801637e5-6d1b-4f95-add9-5e76ace9fd15',
#    'ecbc64b9-702e-42d4-95fa-5c03e18b24bd'],
#   'carry': {'end_location': [19.0, 46.0]}},
#  {'id': '801637e5-6d1b-4f95-add9-5e76ace9fd15',
#   'index': 66,
#   'period': 1,
#   'timestamp': '00:01:16.382',
#   'minute': 1,
#   'second': 16,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 5,
#   'possession_team': {'id': 169, 'name': 'Bayern Munich'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5578, 'name': 'Jérôme Boateng'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [19.0, 46.0],
#   'duration': 2.409134,
#   'related_events': ['26861af8-3380-478d-b251-6dcca9532bdd'],
#   'pass': {'recipient': {'id': 8218, 'name': 'Arjen Robben'},
#    'length': 36.878178,
#    'angle': 0.86217004,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [43.0, 74.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '26861af8-3380-478d-b251-6dcca9532bdd',
# ...
#  {'id': '275f7544-2608-4393-a03a-928b8a792720',
#   'index': 978,
#   'period': 1,
#   'timestamp': '00:22:44.967',
#   'minute': 22,
#   'second': 44,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [48.0, 6.0],
#   'duration': 0.228077,
#   'related_events': ['62b16db8-6559-48e6-aa42-54e869a121e2',
#    'fbade385-8955-4f0e-8723-505427fd980c']},
#  {'id': 'fbade385-8955-4f0e-8723-505427fd980c',
#   'index': 979,
#   'period': 1,
#   'timestamp': '00:22:45.180',
#   'minute': 22,
#   'second': 45,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5658, 'name': 'Łukasz Piszczek'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [71.0, 76.0],
#   'under_pressure': True,
#   'related_events': ['1b19c420-5c10-4157-8929-3ae8f199d8ca',
#    '275f7544-2608-4393-a03a-928b8a792720']},
#  {'id': '62b16db8-6559-48e6-aa42-54e869a121e2',
#   'index': 980,
#   'period': 1,
#   'timestamp': '00:22:45.180',
#   'minute': 22,
#   'second': 45,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5658, 'name': 'Łukasz Piszczek'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [71.0, 76.0],
#   'duration': 0.080023,
#   'under_pressure': True,
#   'related_events': ['0fa97af9-f77c-45d0-84b4-6363688ae022',
#    '275f7544-2608-4393-a03a-928b8a792720',
#    'fbade385-8955-4f0e-8723-505427fd980c'],
#   'carry': {'end_location': [70.0, 76.0]}},
#  {'id': '0fa97af9-f77c-45d0-84b4-6363688ae022',
#   'index': 981,
#   'period': 1,
#   'timestamp': '00:22:45.260',
#   'minute': 22,
#   'second': 45,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5658, 'name': 'Łukasz Piszczek'},
#   'position': {'id': 2, 'name': 'Right Back'},
#   'location': [70.0, 76.0],
#   'duration': 1.250169,
#   'related_events': ['f5120a33-6f03-459e-8a71-dc64ff43f14e'],
#   'pass': {'recipient': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#    'length': 15.033297,
#    'angle': 0.066568166,
#    'height': {'id': 2, 'name': 'Low Pass'},
#    'end_location': [85.0, 77.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'f5120a33-6f03-459e-8a71-dc64ff43f14e',
#   'index': 982,
#   'period': 1,
#   'timestamp': '00:22:46.510',
#   'minute': 22,
#   'second': 46,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [85.0, 77.0],
#   'related_events': ['0fa97af9-f77c-45d0-84b4-6363688ae022']},
#  {'id': 'fdac82a7-ef05-4583-8305-849596331ab6',
#   'index': 983,
#   'period': 1,
#   'timestamp': '00:22:46.510',
#   'minute': 22,
#   'second': 46,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [85.0, 77.0],
#   'duration': 2.310931,
#   'related_events': ['0a417e11-46ec-4a79-9a13-87a5fc79593e',
#    'f5120a33-6f03-459e-8a71-dc64ff43f14e'],
#   'carry': {'end_location': [85.0, 74.0]}},
#  {'id': '0a417e11-46ec-4a79-9a13-87a5fc79593e',
#   'index': 984,
#   'period': 1,
#   'timestamp': '00:22:48.821',
#   'minute': 22,
#   'second': 48,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [85.0, 74.0],
#   'duration': 0.99911,
#   'related_events': ['cefb1cc8-2dda-4eda-9ba4-752d5d6ee94d'],
#   'pass': {'recipient': {'id': 10287, 'name': 'İlkay Gündoğan'},
#    'length': 9.219544,
#    'angle': -2.4329665,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [78.0, 68.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'cefb1cc8-2dda-4eda-9ba4-752d5d6ee94d',
#   'index': 985,
#   'period': 1,
#   'timestamp': '00:22:49.820',
#   'minute': 22,
#   'second': 49,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [78.0, 68.0],
#   'related_events': ['0a417e11-46ec-4a79-9a13-87a5fc79593e']},
#  {'id': '02e9369d-3c73-4fe4-a62b-e7f78ed8d9fc',
#   'index': 986,
#   'period': 1,
#   'timestamp': '00:22:49.820',
#   'minute': 22,
#   'second': 49,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [78.0, 68.0],
#   'duration': 7.47339,
#   'under_pressure': True,
#   'related_events': ['971cb8f6-e38e-442b-89ca-377ff4dc1908',
#    'a3609c6d-bb88-44a8-98ee-f7fa3dcd7dba',
#    'cefb1cc8-2dda-4eda-9ba4-752d5d6ee94d'],
#   'carry': {'end_location': [72.0, 60.0]}},
#  {'id': '971cb8f6-e38e-442b-89ca-377ff4dc1908',
#   'index': 987,
#   'period': 1,
#   'timestamp': '00:22:50.715',
#   'minute': 22,
#   'second': 50,
#   'type': {'id': 17, 'name': 'Pressure'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 5472, 'name': 'Mario Mandžukić'},
#   'position': {'id': 23, 'name': 'Center Forward'},
#   'location': [40.0, 13.0],
#   'duration': 0.358331,
#   'related_events': ['02e9369d-3c73-4fe4-a62b-e7f78ed8d9fc']},
#  {'id': 'a3609c6d-bb88-44a8-98ee-f7fa3dcd7dba',
#   'index': 988,
#   'period': 1,
#   'timestamp': '00:22:57.294',
#   'minute': 22,
#   'second': 57,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [72.0, 60.0],
#   'duration': 1.347673,
#   'related_events': ['7c1898c1-0355-4466-b05c-8020df22d6ca'],
#   'pass': {'recipient': {'id': 4430, 'name': 'Neven Subotić'},
#    'length': 14.3178215,
#    'angle': 1.1383885,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [78.0, 73.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '7c1898c1-0355-4466-b05c-8020df22d6ca',
#   'index': 989,
#   'period': 1,
#   'timestamp': '00:22:58.641',
#   'minute': 22,
#   'second': 58,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 4430, 'name': 'Neven Subotić'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [78.0, 73.0],
#   'related_events': ['a3609c6d-bb88-44a8-98ee-f7fa3dcd7dba']},
#  {'id': 'f168a00a-3c2c-4251-9109-2adcd7d83f96',
#   'index': 990,
#   'period': 1,
#   'timestamp': '00:22:58.641',
#   'minute': 22,
#   'second': 58,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 4430, 'name': 'Neven Subotić'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [78.0, 73.0],
#   'duration': 1.830142,
#   'related_events': ['7c1898c1-0355-4466-b05c-8020df22d6ca',
#    '88e65b20-95df-4e2b-a402-876c256f2dd0'],
#   'carry': {'end_location': [77.0, 68.0]}},
#  {'id': '88e65b20-95df-4e2b-a402-876c256f2dd0',
#   'index': 991,
#   'period': 1,
#   'timestamp': '00:23:00.472',
#   'minute': 23,
#   'second': 0,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 4430, 'name': 'Neven Subotić'},
#   'position': {'id': 3, 'name': 'Right Center Back'},
#   'location': [77.0, 68.0],
#   'duration': 1.847381,
#   'related_events': ['766fe8a0-c30a-4d1b-88df-ac754e365acb'],
#   'pass': {'recipient': {'id': 5572, 'name': 'Mats Hummels'},
#    'length': 32.649654,
#    'angle': -2.0481417,
#    'height': {'id': 1, 'name': 'Ground Pass'},
#    'end_location': [62.0, 39.0],
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '766fe8a0-c30a-4d1b-88df-ac754e365acb',
#   'index': 992,
#   'period': 1,
#   'timestamp': '00:23:02.319',
#   'minute': 23,
#   'second': 2,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5572, 'name': 'Mats Hummels'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [62.0, 39.0],
#   'related_events': ['88e65b20-95df-4e2b-a402-876c256f2dd0']},
#  {'id': 'c684be0e-6aea-439d-9db5-cf7c33f62a4e',
#   'index': 993,
#   'period': 1,
#   'timestamp': '00:23:02.319',
#   'minute': 23,
#   'second': 2,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5572, 'name': 'Mats Hummels'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [62.0, 39.0],
#   'duration': 2.023104,
#   'related_events': ['766fe8a0-c30a-4d1b-88df-ac754e365acb',
#    'd5c8dc20-a316-42b1-8cbe-4e6faa1039f2'],
#   'carry': {'end_location': [68.0, 39.0]}},
#  {'id': 'd5c8dc20-a316-42b1-8cbe-4e6faa1039f2',
#   'index': 994,
#   'period': 1,
#   'timestamp': '00:23:04.342',
#   'minute': 23,
#   'second': 4,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5572, 'name': 'Mats Hummels'},
#   'position': {'id': 5, 'name': 'Left Center Back'},
#   'location': [68.0, 39.0],
#   'duration': 3.260015,
#   'related_events': ['68862a5a-f15e-4d40-b1b9-35634edd0b46',
#    'a1139dc2-82ef-4422-89f2-454bbac2ef10'],
#   'pass': {'recipient': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#    'length': 46.647614,
#    'angle': 0.5404195,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [108.0, 63.0],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': 'a1139dc2-82ef-4422-89f2-454bbac2ef10',
#   'index': 995,
#   'period': 1,
#   'timestamp': '00:23:07.602',
#   'minute': 23,
#   'second': 7,
#   'type': {'id': 42, 'name': 'Ball Receipt*'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 5663, 'name': 'Jakub Błaszczykowski'},
#   'position': {'id': 17, 'name': 'Right Wing'},
#   'location': [104.0, 66.0],
#   'related_events': ['d5c8dc20-a316-42b1-8cbe-4e6faa1039f2'],
#   'ball_receipt': {'outcome': {'id': 9, 'name': 'Incomplete'}}},
#  {'id': '68862a5a-f15e-4d40-b1b9-35634edd0b46',
#   'index': 996,
#   'period': 1,
#   'timestamp': '00:23:07.602',
#   'minute': 23,
#   'second': 7,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [13.0, 18.0],
#   'duration': 0.0,
#   'related_events': ['d5c8dc20-a316-42b1-8cbe-4e6faa1039f2']},
#  {'id': '7fcefbc0-f886-40ee-ac10-0f5a7450dd52',
#   'index': 997,
#   'period': 1,
#   'timestamp': '00:23:07.602',
#   'minute': 23,
#   'second': 7,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [13.0, 18.0],
#   'duration': 0.309185,
#   'related_events': ['68862a5a-f15e-4d40-b1b9-35634edd0b46',
#    'ad5fb193-0856-473c-bf1f-98b3035915f4'],
#   'carry': {'end_location': [12.0, 20.0]}},
#  {'id': 'ad5fb193-0856-473c-bf1f-98b3035915f4',
#   'index': 998,
#   'period': 1,
#   'timestamp': '00:23:07.911',
#   'minute': 23,
#   'second': 7,
#   'type': {'id': 30, 'name': 'Pass'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 169, 'name': 'Bayern Munich'},
#   'player': {'id': 8223, 'name': 'Franck Bilal Ribéry'},
#   'position': {'id': 21, 'name': 'Left Wing'},
#   'location': [12.0, 20.0],
#   'duration': 2.3168,
#   'related_events': ['1fe2c8c9-b1e2-4645-bf84-6a639ab0af6b'],
#   'pass': {'length': 37.01351,
#    'angle': 0.027020449,
#    'height': {'id': 3, 'name': 'High Pass'},
#    'end_location': [49.0, 21.0],
#    'outcome': {'id': 9, 'name': 'Incomplete'},
#    'body_part': {'id': 40, 'name': 'Right Foot'}}},
#  {'id': '1fe2c8c9-b1e2-4645-bf84-6a639ab0af6b',
#   'index': 999,
#   'period': 1,
#   'timestamp': '00:23:10.228',
#   'minute': 23,
#   'second': 10,
#   'type': {'id': 2, 'name': 'Ball Recovery'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [72.0, 60.0],
#   'duration': 0.0,
#   'related_events': ['ad5fb193-0856-473c-bf1f-98b3035915f4']},
#  {'id': 'a5d32da9-6b17-4b86-9c47-3992fee1c013',
#   'index': 1000,
#   'period': 1,
#   'timestamp': '00:23:10.228',
#   'minute': 23,
#   'second': 10,
#   'type': {'id': 43, 'name': 'Carry'},
#   'possession': 52,
#   'possession_team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'play_pattern': {'id': 1, 'name': 'Regular Play'},
#   'team': {'id': 180, 'name': 'Borussia Dortmund'},
#   'player': {'id': 10287, 'name': 'İlkay Gündoğan'},
#   'position': {'id': 11, 'name': 'Left Defensive Midfield'},
#   'location': [72.0, 60.0],
#   'duration': 2.9627,
#   'under_pressure': True,
#   'related_events': ['17781289-9d37-4a11-9b67-b6d7285a57da',
#    '1fe2c8c9-b1e2-4645-bf84-6a639ab0af6b',
#    'd51192b5-9257-4f0d-bd60-5fde1dc3ef06'],
#   'carry': {'end_location': [72.0, 62.0]}},
#  ...]

# %%
data = pd.json_normalize(derklassiker, sep='_').assign(match_id ="18240")
data.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  b31524cb-9a15-4386-9954-f61a93fbb9a2      1       1  00:00:00.000       0
# 1  1b365f44-4d6c-4f60-955d-eb2990a2b0fd      2       1  00:00:00.000       0
# 2  c60553e8-e8a8-4bd4-9e45-9c74dab0bca1      3       1  00:00:00.000       0
# 3  15090649-ebc5-4c08-b54f-719107b67abf      4       1  00:00:00.000       0
# 4  a2615e19-4e6e-46ce-bfe7-9687c5c6fd87      5       1  00:00:00.632       0
#
#    second  possession  duration  type_id    type_name  ...  block_save_block  \
# 0       0           1       0.0       35  Starting XI  ...               NaN
# 1       0           1       0.0       35  Starting XI  ...               NaN
# 2       0           1       0.0       18   Half Start  ...               NaN
# 3       0           1       0.0       18   Half Start  ...               NaN
# 4       0           2       0.4       30         Pass  ...               NaN
#
#   bad_behaviour_card_id  bad_behaviour_card_name foul_committed_type_id  \
# 0                   NaN                      NaN                    NaN
# 1                   NaN                      NaN                    NaN
# 2                   NaN                      NaN                    NaN
# 3                   NaN                      NaN                    NaN
# 4                   NaN                      NaN                    NaN
#
#    foul_committed_type_name substitution_outcome_id  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#    substitution_outcome_name substitution_replacement_id  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#   substitution_replacement_name match_id
# 0                           NaN    18240
# 1                           NaN    18240
# 2                           NaN    18240
# 3                           NaN    18240
# 4                           NaN    18240
#
# [5 rows x 117 columns]

# %%
data['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt*', 'Carry',
#        'Pressure', 'Ball Recovery', 'Dispossessed', 'Duel',
#        'Foul Committed', 'Foul Won', 'Dribbled Past', 'Dribble', 'Block',
#        'Miscontrol', 'Shot', 'Goal Keeper', 'Clearance', 'Interception',
#        'Injury Stoppage', 'Referee Ball-Drop', 'Half End', '50/50',
#        'Bad Behaviour', 'Player Off', 'Player On', 'Substitution'],
#       dtype=object)

# %%
# %matplotlib inline
import json
from pandas.io.json import json_normalize
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Arc, Rectangle, ConnectionPatch
from matplotlib.offsetbox import  OffsetImage
from functools import reduce

# %%
def draw_pitch(ax):
    # size of the pitch is 120, 80
    #Create figure

    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,80], color="black")
    plt.plot([0,120],[80,80], color="black")
    plt.plot([120,120],[80,0], color="black")
    plt.plot([120,0],[0,0], color="black")
    plt.plot([60,60],[0,80], color="black")

    #Left Penalty Area
    plt.plot([14.6,14.6],[57.8,22.2],color="black")
    plt.plot([0,14.6],[57.8,57.8],color="black")
    plt.plot([0,14.6],[22.2,22.2],color="black")

    #Right Penalty Area
    plt.plot([120,105.4],[57.8,57.8],color="black")
    plt.plot([105.4,105.4],[57.8,22.5],color="black")
    plt.plot([120, 105.4],[22.5,22.5],color="black")

    #Left 6-yard Box
    plt.plot([0,4.9],[48,48],color="black")
    plt.plot([4.9,4.9],[48,32],color="black")
    plt.plot([0,4.9],[32,32],color="black")

    #Right 6-yard Box
    plt.plot([120,115.1],[48,48],color="black")
    plt.plot([115.1,115.1],[48,32],color="black")
    plt.plot([120,115.1],[32,32],color="black")

    #Prepare Circles
    centreCircle = plt.Circle((60,40),8.1,color="black",fill=False)
    centreSpot = plt.Circle((60,40),0.71,color="black")
    leftPenSpot = plt.Circle((9.7,40),0.71,color="black")
    rightPenSpot = plt.Circle((110.3,40),0.71,color="black")

    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)

    #Prepare Arcs
    # arguments for arc
    # x, y coordinate of centerpoint of arc
    # width, height as arc might not be circle, but oval
    # angle: degree of rotation of the shape, anti-clockwise
    # theta1, theta2, start and end location of arc in degree
    leftArc = Arc((9.7,40),height=16.2,width=16.2,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((110.3,40),height=16.2,width=16.2,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)

# %%
fig=plt.figure()
fig.set_size_inches(7, 5)
ax=fig.add_subplot(1,1,1)
draw_pitch(ax)
plt.show()

# %%
def heat_pass_map(data, player_name):
    pass_data = data[(data['type_name'] == "Pass") & (data['player_name'] == player_name)]
    action_data = data[(data['player_name']==player_name)]
    
    fig=plt.figure()
    fig.set_size_inches(7, 5)
    ax=fig.add_subplot(1,1,1)
    draw_pitch(ax)
    plt.axis('off')

    for i in range(len(pass_data)):
        # we also differentiate different half by different color
        color = "black"
        ax.annotate("", xy = (pass_data.iloc[i]['pass_end_location'][0], pass_data.iloc[i]['pass_end_location'][1]), xycoords = 'data',
               xytext = (pass_data.iloc[i]['location'][0], pass_data.iloc[i]['location'][1]), textcoords = 'data',
               arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = color),)
    x_coord = [i[0] for i in action_data["location"]]
    y_coord = [i[1] for i in action_data["location"]]
    sns.kdeplot(x_coord, y_coord, shade = "True", color = "red", n_levels = 30)
    plt.ylim(0, 80) # need this, otherwise kde plot will go outside
    plt.xlim(0, 120)
    plt.title('Passes & heatmap:Phillip Lahm')
    plt.show()

# %%
heat_pass_map(df, 'Arjen Robben')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
heat_pass_map(df, 'Philipp Lahm')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
t = sns.load_dataset('tips')

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
p = sns.load_dataset('penguins')

# %%
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_palette("dark")

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(p['bill_depth_mm']);

# %%
sns.histplot(data=p,x="bill_depth_mm", hue="species", multiple="stack");

# %%
sns.kdeplot(data=p,x="bill_depth_mm", hue="species", multiple="stack");

# %%
sns.displot(data=p, x="flipper_length_mm", hue="species", col="species");

# %%
sns.displot(data=p, x="flipper_length_mm", hue="sex", col="species");

# %%
sns.scatterplot(data=p, x="flipper_length_mm", y="bill_length_mm", hue="sex");

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4))
sns.scatterplot(data=p, x="bill_length_mm",y="bill_depth_mm", legend=False, hue="sex", ax=ax[0])
sns.histplot(data=p, x="body_mass_g", hue="sex", ax=ax[1]);

# %%
fig, ax = plt.subplots(1,2,figsize=(8,4),  gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=p, x="bill_length_mm",y="bill_depth_mm", legend=False, hue="sex", ax=ax[0])
sns.histplot(data=p, x="body_mass_g", hue="sex", ax=ax[1], shrink=0.8, alpha=0.8);

# %%
sns.displot(data=p, x="body_mass_g",hue="sex", col="sex");

# %%
sns.displot(data=p, x="island", hue="island");

# %%
sns.pairplot(data=p);

# %%
t.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=t, x="total_bill", col="sex");

# %%
sns.relplot(data=t, x="total_bill", y="tip");

# %%
sns.pairplot(data=t);

# %%
sns.relplot(data=t, x="total_bill", y="tip", hue="smoker");

# %%
sns.relplot(data=t, x="total_bill", y="tip", style='smoker', hue="smoker");

# %%
sns.relplot(data=t, x="total_bill", y="tip", hue="sex");

# %%
sns.relplot(data=t, x="total_bill", y="tip", hue="smoker", style="sex");

# %%
sns.relplot(data=t, x="total_bill", y="tip", hue="size");

# %%
sns.relplot(data=t, x="total_bill", y="tip", hue="size", size="size");

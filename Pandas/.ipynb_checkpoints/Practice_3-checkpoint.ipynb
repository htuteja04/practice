# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dc = pd.read_csv('../../538Datasets/data/comic-characters/comic-characters/dc-wikia-data.csv')

# %%
dc.shape
# Out:
# (6896, 13)

# %%
dc.head()
# Out:
#    page_id                         name                              urlslug  \
# 0     1422         Batman (Bruce Wayne)         \/wiki\/Batman_(Bruce_Wayne)
# 1    23387        Superman (Clark Kent)        \/wiki\/Superman_(Clark_Kent)
# 2     1458   Green Lantern (Hal Jordan)   \/wiki\/Green_Lantern_(Hal_Jordan)
# 3     1659     James Gordon (New Earth)     \/wiki\/James_Gordon_(New_Earth)
# 4     1576  Richard Grayson (New Earth)  \/wiki\/Richard_Grayson_(New_Earth)
#
#                 ID            ALIGN         EYE        HAIR              SEX  \
# 0  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 1  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
# 2  Secret Identity  Good Characters  Brown Eyes  Brown Hair  Male Characters
# 3  Public Identity  Good Characters  Brown Eyes  White Hair  Male Characters
# 4  Secret Identity  Good Characters   Blue Eyes  Black Hair  Male Characters
#
# ...

# %%
dc.columns
# Out:
# Index(['page_id', 'name', 'urlslug', 'ID', 'ALIGN', 'EYE', 'HAIR', 'SEX',
#        'GSM', 'ALIVE', 'APPEARANCES', 'FIRST APPEARANCE', 'YEAR'],
#       dtype='object')

# %%
dc.GSM.isna().sum()
# Out:
# 6832

# %%
dc.loc[(dc['GSM']=='Homosexual Characters')]
# Out:
#       page_id                             name  \
# 65       8856        Renee Montoya (New Earth)
# 119      1862            Todd Rice (New Earth)
# 134      1658      Margaret Sawyer (New Earth)
# 173      1597     Hartley Rathaway (New Earth)
# 253     10139       Holly Robinson (New Earth)
# 315      1618        Anissa Pierce (New Earth)
# 339      1689         Mikaal Tomas (New Earth)
# 348     56388               Mallah (New Earth)
# 397      2708                Brain (New Earth)
# 409      2655         Hugh Dawkins (New Earth)
# 461      1647       Scandal Savage (New Earth)
# 466      3415   Karen Lou Faulkner (New Earth)
# 569      8883       Katherine Kane (New Earth)
# 736     37256            Menalippe (New Earth)
# 780    116529      Ramsey Robinson (New Earth)
# 822     96395     Valerie Kameya (Dakotaverse)
# 855     61669     Aleksandr Creote (New Earth)
# 859     96384       Gerri Brauer (Dakotaverse)
# 894    279711                Karon (New Earth)
# ...

# %%
dc['GSM'] = dc['GSM'].fillna('Straight')

# %%
dc.isna().sum()
# Out:
# page_id                0
# name                   0
# urlslug                0
# ID                  2013
# ALIGN                601
# EYE                 3628
# HAIR                2274
# SEX                  125
# GSM                    0
# ALIVE                  3
# APPEARANCES          355
# FIRST APPEARANCE      69
# YEAR                  69
# dtype: int64

# %%
dc.HAIR.unique()
# Out:
# array(['Black Hair', 'Brown Hair', 'White Hair', 'Blond Hair', 'Red Hair',
#        nan, 'Green Hair', 'Strawberry Blond Hair', 'Grey Hair',
#        'Silver Hair', 'Orange Hair', 'Purple Hair', 'Gold Hair',
#        'Blue Hair', 'Reddish Brown Hair', 'Pink Hair', 'Violet Hair',
#        'Platinum Blond Hair'], dtype=object)

# %%
hair = dc.HAIR.mode()[0]

# %%
dc.HAIR.fillna(hair, inplace=True)

# %%
dc.loc[(dc['ALIVE'] == 'Living Characters')].shape[0]
# Out:
# 5200

# %%
dc['APPEARANCES'].max()
# Out:
# 3093.0

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=dc['SEX'], y=dc['APPEARANCES']);

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=dc['ALIGN'], y=dc['APPEARANCES']);

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x=dc['GSM'], y=dc['APPEARANCES']);

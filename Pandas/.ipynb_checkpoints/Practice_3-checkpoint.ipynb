# %%
import pandas as pd

# %%
import datetime

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
eq = pd.read_csv('Datasets/Earthquake.csv')

# %%
eq
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                             NaN            NaN                  NaN
# 1                             NaN            NaN                  NaN
# 2                             NaN            NaN                  NaN
# 3                             NaN            NaN                  NaN
# 4                             NaN            NaN                  NaN
# ...                           ...            ...                  ...
# 23407                        18.0          42.47                0.120
# 23408                        18.0          48.58                0.129
# 23409                         NaN          91.00                0.992
# 23410                         NaN          26.00                3.553
# 23411                       428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square            ID  Source  \
# 0                   NaN               NaN  ISCGEM860706  ISCGEM
# 1                   NaN               NaN  ISCGEM860737  ISCGEM
# 2                   NaN               NaN  ISCGEM860762  ISCGEM
# 3                   NaN               NaN  ISCGEM860856  ISCGEM
# 4                   NaN               NaN  ISCGEM860890  ISCGEM
# ...                 ...               ...           ...     ...
# 23407               NaN            0.1898    NN00570710      NN
# 23408               NaN            0.2187    NN00570744      NN
# 23409               4.8            1.5200    US10007NAF      US
# 23410               6.0            1.4300    US10007NL0      US
# 23411               4.5            0.9100    US10007NTD      US
#
#       Location Source Magnitude Source     Status
# 0              ISCGEM           ISCGEM  Automatic
# 1              ISCGEM           ISCGEM  Automatic
# 2              ISCGEM           ISCGEM  Automatic
# 3              ISCGEM           ISCGEM  Automatic
# 4              ISCGEM           ISCGEM  Automatic
# ...               ...              ...        ...
# 23407              NN               NN   Reviewed
# 23408              NN               NN   Reviewed
# 23409              US               US   Reviewed
# 23410              US               US   Reviewed
# 23411              US               US   Reviewed
#
# [23412 rows x 21 columns]

# %%
dates = pd.to_datetime(eq['Date'])

# %%
dates
# Out:
# 0        1965-01-02 00:00:00
# 1        1965-01-04 00:00:00
# 2        1965-01-05 00:00:00
# 3        1965-01-08 00:00:00
# 4        1965-01-09 00:00:00
#                 ...
# 23407    2016-12-28 00:00:00
# 23408    2016-12-28 00:00:00
# 23409    2016-12-28 00:00:00
# 23410    2016-12-29 00:00:00
# 23411    2016-12-30 00:00:00
# Name: Date, Length: 23412, dtype: object

# %%
date_lengths = eq.Date.str.len()
date_lengths.value_counts()
# Out:
# 10    23409
# 24        3
# Name: Date, dtype: int64

# %% [markdown]
# checking for consistent data entry

# %%
date_lengths
# Out:
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
#          ..
# 23407    10
# 23408    10
# 23409    10
# 23410    10
# 23411    10
# Name: Date, Length: 23412, dtype: int64

# %%
idc = np.where([date_lengths == 24])[1]

# %%
eq.loc[idc, 'Date']
# Out:
# 3378     1975-02-23T02:58:41.000Z
# 7512     1985-04-28T02:53:41.530Z
# 20650    2011-03-13T02:23:34.520Z
# Name: Date, dtype: object

# %%
eq.loc[3378, "Date"] = "02/23/1975"
eq.loc[7512, "Date"] = "04/28/1985"
eq.loc[20650, "Date"] = "03/13/2011"

# %%
eq['Date'] = pd.to_datetime(eq['Date'])

# %%
eq['Date']
# Out:
# 0       1965-01-02
# 1       1965-01-04
# 2       1965-01-05
# 3       1965-01-08
# 4       1965-01-09
#            ...
# 23407   2016-12-28
# 23408   2016-12-28
# 23409   2016-12-28
# 23410   2016-12-29
# 23411   2016-12-30
# Name: Date, Length: 23412, dtype: datetime64[ns]

# %%
eq['Year'] = eq['Date'].dt.year
eq['Month'] = eq['Date'].dt.month

# %%
eq
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 0     1965-01-02  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1     1965-01-04  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2     1965-01-05  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3     1965-01-08  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4     1965-01-09  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...          ...       ...       ...        ...         ...     ...
# 23407 2016-12-28  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408 2016-12-28  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409 2016-12-28  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410 2016-12-29  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Horizontal Distance  Horizontal Error  Root Mean Square            ID  \
# 0                      NaN               NaN               NaN  ISCGEM860706
# 1                      NaN               NaN               NaN  ISCGEM860737
# 2                      NaN               NaN               NaN  ISCGEM860762
# 3                      NaN               NaN               NaN  ISCGEM860856
# 4                      NaN               NaN               NaN  ISCGEM860890
# ...                    ...               ...               ...           ...
# 23407                0.120               NaN            0.1898    NN00570710
# 23408                0.129               NaN            0.2187    NN00570744
# 23409                0.992               4.8            1.5200    US10007NAF
# 23410                3.553               6.0            1.4300    US10007NL0
# 23411                0.681               4.5            0.9100    US10007NTD
#
#        Source  Location Source Magnitude Source     Status  Year Month
# 0      ISCGEM           ISCGEM           ISCGEM  Automatic  1965     1
# 1      ISCGEM           ISCGEM           ISCGEM  Automatic  1965     1
# 2      ISCGEM           ISCGEM           ISCGEM  Automatic  1965     1
# 3      ISCGEM           ISCGEM           ISCGEM  Automatic  1965     1
# 4      ISCGEM           ISCGEM           ISCGEM  Automatic  1965     1
# ...       ...              ...              ...        ...   ...   ...
# 23407      NN               NN               NN   Reviewed  2016    12
# 23408      NN               NN               NN   Reviewed  2016    12
# 23409      US               US               US   Reviewed  2016    12
# 23410      US               US               US   Reviewed  2016    12
# 23411      US               US               US   Reviewed  2016    12
#
# [23412 rows x 23 columns]

# %%
eq[['Month', 'Year']].isna().sum()
# Out:
# Month    0
# Year     0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(eq['Month'], bins=12);

# %%
len(eq.Year.unique())
# Out:
# 52

# %%
sns.displot(eq.Year, bins=52);

# %%
year_count  = eq.groupby('Year').Year.count()

# %%
plt.figure(figsize=(25,8))
sns.barplot(x=year_count.index, y=year_count.values);

# %%
eq = eq.drop(['ID', 'Source'],axis=1)

# %%
eq
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 0     1965-01-02  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1     1965-01-04  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2     1965-01-05  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3     1965-01-08  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4     1965-01-09  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...          ...       ...       ...        ...         ...     ...
# 23407 2016-12-28  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408 2016-12-28  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409 2016-12-28  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410 2016-12-29  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0              NaN                     NaN        6.0             MW  ...
# 1              NaN                     NaN        5.8             MW  ...
# 2              NaN                     NaN        6.2             MW  ...
# 3              NaN                     NaN        5.8             MW  ...
# 4              NaN                     NaN        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                     NaN        5.9            MWW  ...
# 23410          1.8                     NaN        6.3            MWW  ...
# 23411          2.2                     NaN        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                             NaN            NaN                  NaN
# 1                             NaN            NaN                  NaN
# 2                             NaN            NaN                  NaN
# 3                             NaN            NaN                  NaN
# 4                             NaN            NaN                  NaN
# ...                           ...            ...                  ...
# 23407                        18.0          42.47                0.120
# 23408                        18.0          48.58                0.129
# 23409                         NaN          91.00                0.992
# 23410                         NaN          26.00                3.553
# 23411                       428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square  Location Source Magnitude Source  \
# 0                   NaN               NaN           ISCGEM           ISCGEM
# 1                   NaN               NaN           ISCGEM           ISCGEM
# 2                   NaN               NaN           ISCGEM           ISCGEM
# 3                   NaN               NaN           ISCGEM           ISCGEM
# 4                   NaN               NaN           ISCGEM           ISCGEM
# ...                 ...               ...              ...              ...
# 23407               NaN            0.1898               NN               NN
# 23408               NaN            0.2187               NN               NN
# 23409               4.8            1.5200               US               US
# 23410               6.0            1.4300               US               US
# 23411               4.5            0.9100               US               US
#
#           Status  Year  Month
# 0      Automatic  1965      1
# 1      Automatic  1965      1
# 2      Automatic  1965      1
# 3      Automatic  1965      1
# 4      Automatic  1965      1
# ...          ...   ...    ...
# 23407   Reviewed  2016     12
# 23408   Reviewed  2016     12
# 23409   Reviewed  2016     12
# 23410   Reviewed  2016     12
# 23411   Reviewed  2016     12
#
# [23412 rows x 21 columns]

# %%
eq['Magnitude Type'].unique()
# Out:
# array(['MW', 'ML', 'MH', 'MS', 'MB', 'MWC', 'MD', nan, 'MWB', 'MWW',
#        'MWR'], dtype=object)

# %%
eq['Type'].unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
eq['Status'].unique()
# Out:
# array(['Automatic', 'Reviewed'], dtype=object)

# %% [markdown]
# Data dictionary
#
# - depth: Earthquakes can occur anywhere between the Earth's surface and about 700 kilometers below the surface. For scientific purposes, this earthquake depth range of 0 - 700 km is divided into three zones: shallow, intermediate, and deep.
# Shallow earthquakes are between 0 and 70 km deep; intermediate earthquakes, 70 - 300 km deep; and deep earthquakes, 300 - 700 km deep. In general, the term "deep-focus earthquakes" is applied to earthquakes deeper than 70 km.
#
# ![Earthquake_magnitude_scale.JPG](attachment:Earthquake_magnitude_scale.JPG)
#
#
# - Azimuthal gap is the maximum angle separating two adjacent seismic stations, both measured from the epicenter of an earthquake (Fig. 7). If azimuthal gap is more than 180°, the location accuracy degrades significantly

# %% [markdown]
# ![Azimuthal_gap.JPG](attachment:Azimuthal_gap.JPG)

# %%
eq['Depth'].mean()
# Out:
# 70.76791124209808

# %%
eq['Magnitude'].max()
# Out:
# 9.1

# %%
eq['Magnitude'].mean()
# Out:
# 5.882530753460003

# %%
eq.groupby('Type').size()
# Out:
# Type
# Earthquake           23232
# Explosion                4
# Nuclear Explosion      175
# Rock Burst               1
# dtype: int64

# %%
eq[['Date', 'Type', 'Depth', 'Magnitude', 'Azimuthal Gap', 'Horizontal Distance', 'Latitude', 'Longitude']].isna().sum()
# Out:
# Date                       0
# Type                       0
# Depth                      0
# Magnitude                  0
# Azimuthal Gap          16113
# Horizontal Distance    21808
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
eq.shape[0]
# Out:
# 23412

# %%
eq = eq.drop(['Horizontal Distance', 'Azimuthal Gap'], axis=1)

# %%
eq
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 0     1965-01-02  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1     1965-01-04  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2     1965-01-05  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3     1965-01-08  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4     1965-01-09  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...          ...       ...       ...        ...         ...     ...
# 23407 2016-12-28  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408 2016-12-28  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409 2016-12-28  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410 2016-12-29  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0              NaN                     NaN        6.0             MW
# 1              NaN                     NaN        5.8             MW
# 2              NaN                     NaN        6.2             MW
# 3              NaN                     NaN        5.8             MW
# 4              NaN                     NaN        5.8             MW
# ...            ...                     ...        ...            ...
# 23407          1.2                    40.0        5.6             ML
# 23408          2.0                    33.0        5.5             ML
# 23409          1.8                     NaN        5.9            MWW
# 23410          1.8                     NaN        6.3            MWW
# 23411          2.2                     NaN        5.5             MB
#
#        Magnitude Error  Magnitude Seismic Stations  Horizontal Error  \
# 0                  NaN                         NaN               NaN
# 1                  NaN                         NaN               NaN
# 2                  NaN                         NaN               NaN
# 3                  NaN                         NaN               NaN
# 4                  NaN                         NaN               NaN
# ...                ...                         ...               ...
# 23407            0.320                        18.0               NaN
# 23408            0.260                        18.0               NaN
# 23409              NaN                         NaN               4.8
# 23410              NaN                         NaN               6.0
# 23411            0.029                       428.0               4.5
#
#        Root Mean Square Location Source Magnitude Source     Status  Year  \
# 0                   NaN          ISCGEM           ISCGEM  Automatic  1965
# 1                   NaN          ISCGEM           ISCGEM  Automatic  1965
# 2                   NaN          ISCGEM           ISCGEM  Automatic  1965
# 3                   NaN          ISCGEM           ISCGEM  Automatic  1965
# 4                   NaN          ISCGEM           ISCGEM  Automatic  1965
# ...                 ...             ...              ...        ...   ...
# 23407            0.1898              NN               NN   Reviewed  2016
# 23408            0.2187              NN               NN   Reviewed  2016
# 23409            1.5200              US               US   Reviewed  2016
# 23410            1.4300              US               US   Reviewed  2016
# 23411            0.9100              US               US   Reviewed  2016
#
#        Month
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 23407     12
# 23408     12
# 23409     12
# 23410     12
# 23411     12
#
# [23412 rows x 19 columns]

# %%
sns.histplot(eq['Magnitude']);

# %%
eq['Depth'].quantile(0.25)
# Out:
# 14.522499999999999

# %%
eq['Depth'].quantile(0.5)
# Out:
# 33.0

# %%
eq['Depth'].quantile(0.75)
# Out:
# 54.0

# %% [markdown]
# more data viz through Tableau

# %%
eq = eq.drop(['Location Source', 'Magnitude Source'], axis=1)

# %%
eq
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 0     1965-01-02  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1     1965-01-04  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2     1965-01-05  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3     1965-01-08  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4     1965-01-09  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...          ...       ...       ...        ...         ...     ...
# 23407 2016-12-28  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408 2016-12-28  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409 2016-12-28  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410 2016-12-29  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0              NaN                     NaN        6.0             MW
# 1              NaN                     NaN        5.8             MW
# 2              NaN                     NaN        6.2             MW
# 3              NaN                     NaN        5.8             MW
# 4              NaN                     NaN        5.8             MW
# ...            ...                     ...        ...            ...
# 23407          1.2                    40.0        5.6             ML
# 23408          2.0                    33.0        5.5             ML
# 23409          1.8                     NaN        5.9            MWW
# 23410          1.8                     NaN        6.3            MWW
# 23411          2.2                     NaN        5.5             MB
#
#        Magnitude Error  Magnitude Seismic Stations  Horizontal Error  \
# 0                  NaN                         NaN               NaN
# 1                  NaN                         NaN               NaN
# 2                  NaN                         NaN               NaN
# 3                  NaN                         NaN               NaN
# 4                  NaN                         NaN               NaN
# ...                ...                         ...               ...
# 23407            0.320                        18.0               NaN
# 23408            0.260                        18.0               NaN
# 23409              NaN                         NaN               4.8
# 23410              NaN                         NaN               6.0
# 23411            0.029                       428.0               4.5
#
#        Root Mean Square     Status  Year  Month
# 0                   NaN  Automatic  1965      1
# 1                   NaN  Automatic  1965      1
# 2                   NaN  Automatic  1965      1
# 3                   NaN  Automatic  1965      1
# 4                   NaN  Automatic  1965      1
# ...                 ...        ...   ...    ...
# 23407            0.1898   Reviewed  2016     12
# 23408            0.2187   Reviewed  2016     12
# 23409            1.5200   Reviewed  2016     12
# 23410            1.4300   Reviewed  2016     12
# 23411            0.9100   Reviewed  2016     12
#
# [23412 rows x 17 columns]

# %%
eq.to_csv('Datasets/eq_modified.csv')

# %%
eq[eq['Magnitude'] == 5.5]
# Out:
#             Date      Time  Latitude  Longitude        Type  Depth  \
# 12    1965-01-29  09:35:30   54.6360   161.7030  Earthquake  55.00
# 69    1965-03-01  09:08:48   -5.3710   152.0550  Earthquake  40.00
# 78    1965-03-05  06:15:04   50.9280   179.5110  Earthquake  30.00
# 151   1965-05-19  13:59:55   -4.8190   152.4360  Earthquake  50.00
# 166   1965-06-11  07:11:04   44.1330   149.2550  Earthquake  31.60
# ...          ...       ...       ...        ...         ...    ...
# 23390 2016-12-18  06:15:46  -34.9886  -107.8694  Earthquake  10.00
# 23393 2016-12-18  11:35:48  -10.1904   161.2187  Earthquake  57.52
# 23398 2016-12-20  20:07:53  -10.1549   160.7816  Earthquake  10.38
# 23408 2016-12-28  09:13:47   38.3777  -118.8957  Earthquake   8.80
# 23411 2016-12-30  20:08:28   37.3973   141.4103  Earthquake  11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 12             NaN                     NaN        5.5             MW
# 69             NaN                     NaN        5.5             MW
# 78             NaN                     NaN        5.5             MW
# 151            NaN                     NaN        5.5             MW
# 166            NaN                     NaN        5.5             MW
# ...            ...                     ...        ...            ...
# 23390          1.6                     NaN        5.5            MWB
# 23393          5.2                     NaN        5.5             MB
# 23398          3.2                     NaN        5.5            MWB
# 23408          2.0                    33.0        5.5             ML
# 23411          2.2                     NaN        5.5             MB
#
#        Magnitude Error  Magnitude Seismic Stations  Horizontal Error  \
# 12                 NaN                         NaN               NaN
# 69                 NaN                         NaN               NaN
# 78                 NaN                         NaN               NaN
# 151                NaN                         NaN               NaN
# 166                NaN                         NaN               NaN
# ...                ...                         ...               ...
# 23390            0.110                         8.0              11.9
# 23393            0.048                       147.0               8.8
# 23398            0.048                        41.0               7.0
# 23408            0.260                        18.0               NaN
# 23411            0.029                       428.0               4.5
#
#        Root Mean Square     Status  Year  Month
# 12                  NaN  Automatic  1965      1
# 69                  NaN  Automatic  1965      3
# 78                  NaN  Automatic  1965      3
# 151                 NaN  Automatic  1965      5
# 166                 NaN  Automatic  1965      6
# ...                 ...        ...   ...    ...
# 23390            0.8000   Reviewed  2016     12
# 23393            0.7900   Reviewed  2016     12
# 23398            0.7000   Reviewed  2016     12
# 23408            0.2187   Reviewed  2016     12
# 23411            0.9100   Reviewed  2016     12
#
# [4685 rows x 17 columns]

# %%
eq[eq['Magnitude'] == 6.0]
# Out:
#             Date      Time  Latitude  Longitude        Type   Depth  \
# 0     1965-01-02  13:44:18   19.2460   145.6160  Earthquake  131.60
# 7     1965-01-15  23:17:42  -13.3090   166.2120  Earthquake   35.00
# 8     1965-01-16  11:32:37  -56.4520   -27.0430  Earthquake   95.00
# 14    1965-02-02  15:56:51   37.5230    73.2510  Earthquake   15.00
# 17    1965-02-04  06:04:59   51.6390   175.0550  Earthquake   30.00
# ...          ...       ...       ...        ...         ...     ...
# 23367 2016-12-08  05:15:05   43.8229    86.3451  Earthquake   17.55
# 23380 2016-12-10  16:24:35   -5.6593   154.4734  Earthquake  142.58
# 23383 2016-12-14  02:01:23   21.2897   144.4037  Earthquake   22.37
# 23397 2016-12-20  12:33:14  -10.1785   160.9149  Earthquake   10.00
# 23401 2016-12-24  01:32:16   -5.2453   153.5754  Earthquake   35.00
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  \
# 0              NaN                     NaN        6.0             MW
# 7              NaN                     NaN        6.0             MW
# 8              NaN                     NaN        6.0             MW
# 14             NaN                     NaN        6.0             MW
# 17             NaN                     NaN        6.0             MW
# ...            ...                     ...        ...            ...
# 23367          2.9                     NaN        6.0            MWW
# 23380          3.9                     NaN        6.0            MWW
# 23383          1.8                     NaN        6.0            MWW
# 23397          1.6                     NaN        6.0            MWW
# 23401          1.9                     NaN        6.0            MWW
#
#        Magnitude Error  Magnitude Seismic Stations  Horizontal Error  \
# 0                  NaN                         NaN               NaN
# 7                  NaN                         NaN               NaN
# 8                  NaN                         NaN               NaN
# 14                 NaN                         NaN               NaN
# 17                 NaN                         NaN               NaN
# ...                ...                         ...               ...
# 23367              NaN                         NaN               7.4
# 23380              NaN                         NaN               8.6
# 23383              NaN                         NaN               7.3
# 23397              NaN                         NaN               5.7
# 23401              NaN                         NaN               6.9
#
#        Root Mean Square     Status  Year  Month
# 0                   NaN  Automatic  1965      1
# 7                   NaN  Automatic  1965      1
# 8                   NaN  Automatic  1965      1
# 14                  NaN  Automatic  1965      2
# 17                  NaN  Automatic  1965      2
# ...                 ...        ...   ...    ...
# 23367              0.82   Reviewed  2016     12
# 23380              0.80   Reviewed  2016     12
# 23383              1.01   Reviewed  2016     12
# 23397              0.88   Reviewed  2016     12
# 23401              0.91   Reviewed  2016     12
#
# [1580 rows x 17 columns]

# %% [markdown]
# ![Dashboard%201.png](attachment:Dashboard%201.png)

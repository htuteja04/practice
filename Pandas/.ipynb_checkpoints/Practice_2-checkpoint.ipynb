# %%
import pandas as pd
import numpy as np

# %%
cvd = pd.read_csv('Datasets/covid.csv')

# %%
cvd.size
# Out:
# 10168992

# %%
cvd.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
cvd.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.491540e+05  1.490300e+05        1.478790e+05  1.319890e+05
# mean   2.109497e+06  8.156646e+03        8.098208e+03  5.234021e+04
# std    1.250288e+07  4.594042e+04        4.427885e+04  2.753371e+05
# min    1.000000e+00 -7.434700e+04       -6.223000e+03  1.000000e+00
# 25%    1.542250e+03  1.000000e+00        5.714000e+00  6.700000e+01
# 50%    2.022100e+04  6.900000e+01        9.000000e+01  6.680000e+02
# 75%    2.531838e+05  9.120000e+02        9.633575e+02  6.413000e+03
# max    2.901468e+08  1.949468e+06        1.450119e+06  5.443578e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  132139.000000        132007.000000            148458.000000
# mean      170.900574           170.531834             23071.035195
# std       832.769116           813.988845             37617.190174
# min     -1918.000000          -232.143000                 0.001000
# ...

# %%
cvd.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
cvd.groupby('continent').size()
# Out:
# continent
# Africa           36007
# Asia             33198
# Europe           33918
# North America    22756
# Oceania           7971
# South America     8776
# dtype: int64

# %%
cvd.groupby('location')['life_expectancy'].agg(['mean'])
# Out:
#                     mean
# location
# Afghanistan        64.83
# Africa               NaN
# Albania            78.57
# Algeria            76.88
# Andorra            83.73
# ...                  ...
# Wallis and Futuna  79.94
# World              72.58
# Yemen              66.12
# Zambia             63.89
# Zimbabwe           61.49
#
# [238 rows x 1 columns]

# %%
cvd[['iso_code','gdp_per_capita']]
# Out:
#        iso_code  gdp_per_capita
# 0           AFG        1803.987
# 1           AFG        1803.987
# 2           AFG        1803.987
# 3           AFG        1803.987
# 4           AFG        1803.987
# ...         ...             ...
# 151771      ZWE        1899.775
# 151772      ZWE        1899.775
# 151773      ZWE        1899.775
# 151774      ZWE        1899.775
# 151775      ZWE        1899.775
#
# [151776 rows x 2 columns]

# %%
cvd.groupby('location')['gdp_per_capita'].agg(['mean'])
# Out:
#                         mean
# location
# Afghanistan         1803.987
# Africa                   NaN
# Albania            11803.431
# Algeria            13913.839
# Andorra                  NaN
# ...                      ...
# Wallis and Futuna        NaN
# World              15469.207
# Yemen               1479.147
# Zambia              3689.251
# Zimbabwe            1899.775
#
# [238 rows x 1 columns]

# %%
cvd.groupby('location')['population_density'].agg(['mean'])
# Out:
#                       mean
# location
# Afghanistan         54.422
# Africa                 NaN
# Albania            104.871
# Algeria             17.348
# Andorra            163.755
# ...                    ...
# Wallis and Futuna      NaN
# World               58.045
# Yemen               53.508
# Zambia              22.995
# Zimbabwe            42.729
#
# [238 rows x 1 columns]

# %%
cvd.groupby('location')['median_age'].agg(['mean'])
# Out:
#                    mean
# location
# Afghanistan        18.6
# Africa              NaN
# Albania            38.0
# Algeria            29.1
# Andorra             NaN
# ...                 ...
# Wallis and Futuna   NaN
# World              30.9
# Yemen              20.3
# Zambia             17.7
# Zimbabwe           19.6
#
# [238 rows x 1 columns]

# %%
Africa_df = cvd.loc[(cvd.continent == 'Africa')]

# %%
Africa_df.size
# Out:
# 2412469

# %%
Africa_df.isna().sum()[:15]
# Out:
# iso_code                             0
# continent                            0
# location                             0
# date                                 0
# total_cases                         88
# new_cases                          142
# new_cases_smoothed                 416
# total_deaths                      2455
# new_deaths                        2466
# new_deaths_smoothed               2481
# total_cases_per_million             88
# new_cases_per_million              142
# new_cases_smoothed_per_million     416
# total_deaths_per_million          2455
# new_deaths_per_million            2466
# dtype: int64

# %%
Africa_df.isna().sum()[15:30]
# Out:
# new_deaths_smoothed_per_million        2481
# reproduction_rate                      3195
# icu_patients                          35537
# icu_patients_per_million              35537
# hosp_patients                         36007
# hosp_patients_per_million             36007
# weekly_icu_admissions                 36007
# weekly_icu_admissions_per_million     36007
# weekly_hosp_admissions                35920
# weekly_hosp_admissions_per_million    35920
# new_tests                             26237
# total_tests                           26535
# total_tests_per_thousand              26535
# new_tests_per_thousand                26237
# new_tests_smoothed                    23322
# dtype: int64

# %%
Africa_df.isna().sum()[30:45]
# Out:
# new_tests_smoothed_per_thousand          23322
# positive_rate                            23703
# tests_per_case                           23796
# tests_units                              22082
# total_vaccinations                       32084
# people_vaccinated                        32310
# people_fully_vaccinated                  33154
# total_boosters                           35945
# new_vaccinations                         33964
# new_vaccinations_smoothed                21663
# total_vaccinations_per_hundred           32084
# people_vaccinated_per_hundred            32310
# people_fully_vaccinated_per_hundred      33154
# total_boosters_per_hundred               35945
# new_vaccinations_smoothed_per_million    21663
# dtype: int64

# %%
Africa_df.isna().sum()[45:67]
# Out:
# new_people_vaccinated_smoothed                21723
# new_people_vaccinated_smoothed_per_hundred    21723
# stringency_index                               3910
# population                                        0
# population_density                             1121
# median_age                                      483
# aged_65_older                                   483
# aged_70_older                                   483
# gdp_per_capita                                 1141
# extreme_poverty                                9017
# cardiovasc_death_rate                           483
# diabetes_prevalence                             483
# female_smokers                                12295
# male_smokers                                  12295
# handwashing_facilities                         7069
# hospital_beds_per_thousand                     9637
# life_expectancy                                   0
# human_development_index                        1141
# ...

# %%
Asia_df = cvd.loc[(cvd.continent == 'Asia')]

# %%
Asia_df.size
# Out:
# 2224266

# %%
Europe_df = cvd.loc[(cvd.continent == 'Europe')]

# %%
Europe_df.size
# Out:
# 2272506

# %%
Asia_df.groupby('location')['life_expectancy'].mean()
# Out:
# location
# Afghanistan             64.83
# Armenia                 75.09
# Azerbaijan              73.00
# Bahrain                 77.29
# Bangladesh              72.59
# Bhutan                  71.78
# Brunei                  75.86
# Cambodia                69.82
# China                   76.91
# Georgia                 73.77
# Hong Kong               84.86
# India                   69.66
# Indonesia               71.72
# Iran                    76.68
# Iraq                    70.60
# Israel                  82.97
# Japan                   84.63
# Jordan                  74.53
# Kazakhstan              73.60
# Kuwait                  75.49
# Kyrgyzstan              71.45
# Laos                    67.92
# Lebanon                 78.93
# Macao                   84.24
# Malaysia                76.16
# Maldives                78.92
# Mongolia                69.87
# Myanmar                 67.13
# Nepal                   70.78
# Northern Cyprus           NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# [Date time analysis guide](https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
vlc = pd.read_csv('Datasets/vlc.csv')

# %%
vlc
# Out:
#       Number                       Name         Country  \
# 0     210010  West Eifel Volcanic Field         Germany
# 1     210020            Chaine des Puys          France
# 2     210030        Olot Volcanic Field           Spain
# 3     210040   Calatrava Volcanic Field           Spain
# 4     211001                 Larderello           Italy
# ...      ...                        ...             ...
# 1503  390130                 Zavodovski  United Kingdom
# 1504  390140        Protector Seamounts  United Kingdom
# 1505  390812            Rittmann, Mount      Antarctica
# 1506  390829          James Ross Island      Antarctica
# 1507  390847                   Melville      Antarctica
#
#                               Region                 Type  \
# 0     Mediterranean and Western Asia              Maar(s)
# 1     Mediterranean and Western Asia         Lava dome(s)
# 2     Mediterranean and Western Asia  Pyroclastic cone(s)
# 3     Mediterranean and Western Asia  Pyroclastic cone(s)
# 4     Mediterranean and Western Asia  Explosion crater(s)
# ...                              ...                  ...
# 1503                      Antarctica        Stratovolcano
# 1504                      Antarctica            Submarine
# 1505                      Antarctica               Shield
# 1506                      Antarctica               Shield
# 1507                      Antarctica        Stratovolcano
#
#          Activity Evidence Last Known Eruption  Latitude  Longitude  \
# 0           Eruption Dated            8300 BCE    50.170      6.850
# 1           Eruption Dated            4040 BCE    45.775      2.970
# 2        Evidence Credible             Unknown    42.170      2.530
# 3           Eruption Dated            3600 BCE    38.870     -4.020
# 4        Eruption Observed             1282 CE    43.250     10.870
# ...                    ...                 ...       ...        ...
# 1503     Eruption Observed             2016 CE   -56.300    -27.570
# 1504     Eruption Observed             1962 CE   -55.912    -28.167
# 1505  Unrest / Pleistocene             Unknown   -73.450    165.500
# 1506     Evidence Credible             Unknown   -64.150    -57.750
# 1507    Evidence Uncertain             Unknown   -62.020    -57.670
#
#       Elevation (Meters)                Dominant Rock Type  \
# 0                    600                           Foidite
# 1                   1464             Basalt / Picro-Basalt
# 2                    893  Trachybasalt / Tephrite Basanite
# 3                   1117             Basalt / Picro-Basalt
# 4                    500                           No Data
# ...                  ...                               ...
# 1503                 551             Basalt / Picro-Basalt
# 1504                 -55                          Rhyolite
# 1505                2600                               NaN
# 1506                1630             Basalt / Picro-Basalt
# 1507                 549                               NaN
#
#                                   Tectonic Setting
# 0           Rift Zone / Continental Crust (>25 km)
# 1           Rift Zone / Continental Crust (>25 km)
# 2          Intraplate / Continental Crust (>25 km)
# 3          Intraplate / Continental Crust (>25 km)
# 4     Subduction Zone / Continental Crust (>25 km)
# ...                                            ...
# 1503     Subduction Zone / Oceanic Crust (< 15 km)
# 1504     Subduction Zone / Oceanic Crust (< 15 km)
# 1505       Intraplate / Continental Crust (>25 km)
# 1506       Intraplate / Continental Crust (>25 km)
# 1507       Intraplate / Continental Crust (>25 km)
#
# [1508 rows x 12 columns]

# %%
vlc['Last Known Eruption']
# Out:
# 0       8300 BCE
# 1       4040 BCE
# 2        Unknown
# 3       3600 BCE
# 4        1282 CE
#           ...
# 1503     2016 CE
# 1504     1962 CE
# 1505     Unknown
# 1506     Unknown
# 1507     Unknown
# Name: Last Known Eruption, Length: 1508, dtype: object

# %%
vlc.groupby('Last Known Eruption').Number.count()
# Out:
# Last Known Eruption
# 0 CE           1
# 1000 CE        1
# 1007 CE        1
# 104 BCE        1
# 10450 BCE      1
#             ...
# 950 CE         6
# 9540 BCE       1
# 960 BCE        1
# 960 CE         1
# Unknown      637
# Name: Number, Length: 399, dtype: int64

# %%
vlc = vlc[vlc['Last Known Eruption'] != 'Unknown']

# %%
vlc.groupby('Last Known Eruption').Name.count()
# Out:
# Last Known Eruption
# 0 CE         1
# 1000 CE      1
# 1007 CE      1
# 104 BCE      1
# 10450 BCE    1
#             ..
# 950 BCE      1
# 950 CE       6
# 9540 BCE     1
# 960 BCE      1
# 960 CE       1
# Name: Name, Length: 398, dtype: int64

# %%
vlc.shape
# Out:
# (871, 12)

# %%
vlc['Last Known Eruption'].isna().sum()
# Out:
# 0

# %%
# !pip install flexidate
# Out:
# Requirement already satisfied: flexidate in c:\users\tutej\anaconda3\lib\site-packages (1.4)
# Requirement already satisfied: python-dateutil>=2.5 in c:\users\tutej\anaconda3\lib\site-packages (from flexidate) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tutej\anaconda3\lib\site-packages (from python-dateutil>=2.5->flexidate) (1.16.0)

# %%
from flexidate import parse

# %%
fd_ce = parse('2016 CE')

# %%
fd_ce
# Out:
# <class 'flexidate.FlexiDate'> 2016

# %%
fd_ce.year
# Out:
# '2016'

# %%
vlc['Last Known Eruption']
# Out:
# 0       8300 BCE
# 1       4040 BCE
# 3       3600 BCE
# 4        1282 CE
# 5        104 BCE
#           ...
# 1498     2007 CE
# 1499     2015 CE
# 1500     1911 CE
# 1503     2016 CE
# 1504     1962 CE
# Name: Last Known Eruption, Length: 871, dtype: object

# %%
vlc.update("'"+vlc['Last Known Eruption'].astype(str)+"'")

# %%
vlc
# Out:
#       Number                       Name         Country  \
# 0     210010  West Eifel Volcanic Field         Germany
# 1     210020            Chaine des Puys          France
# 3     210040   Calatrava Volcanic Field           Spain
# 4     211001                 Larderello           Italy
# 5     211003                    Vulsini           Italy
# ...      ...                        ...             ...
# 1498  390081             Montagu Island  United Kingdom
# 1499  390090                   Saunders  United Kingdom
# 1500  390100           Candlemas Island  United Kingdom
# 1503  390130                 Zavodovski  United Kingdom
# 1504  390140        Protector Seamounts  United Kingdom
#
#                               Region                 Type  Activity Evidence  \
# 0     Mediterranean and Western Asia              Maar(s)     Eruption Dated
# 1     Mediterranean and Western Asia         Lava dome(s)     Eruption Dated
# 3     Mediterranean and Western Asia  Pyroclastic cone(s)     Eruption Dated
# 4     Mediterranean and Western Asia  Explosion crater(s)  Eruption Observed
# 5     Mediterranean and Western Asia              Caldera  Eruption Observed
# ...                              ...                  ...                ...
# 1498                      Antarctica               Shield  Eruption Observed
# 1499                      Antarctica        Stratovolcano  Eruption Observed
# 1500                      Antarctica        Stratovolcano  Eruption Observed
# 1503                      Antarctica        Stratovolcano  Eruption Observed
# 1504                      Antarctica            Submarine  Eruption Observed
#
#      Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 0             '8300 BCE'    50.170      6.850                 600
# 1             '4040 BCE'    45.775      2.970                1464
# 3             '3600 BCE'    38.870     -4.020                1117
# 4              '1282 CE'    43.250     10.870                 500
# 5              '104 BCE'    42.600     11.930                 800
# ...                  ...       ...        ...                 ...
# 1498           '2007 CE'   -58.445    -26.374                1370
# 1499           '2015 CE'   -57.800    -26.483                 843
# 1500           '1911 CE'   -57.080    -26.670                 550
# 1503           '2016 CE'   -56.300    -27.570                 551
# 1504           '1962 CE'   -55.912    -28.167                 -55
#
#            Dominant Rock Type                              Tectonic Setting
# 0                     Foidite        Rift Zone / Continental Crust (>25 km)
# 1       Basalt / Picro-Basalt        Rift Zone / Continental Crust (>25 km)
# 3       Basalt / Picro-Basalt       Intraplate / Continental Crust (>25 km)
# 4                     No Data  Subduction Zone / Continental Crust (>25 km)
# 5     Trachyte / Trachydacite  Subduction Zone / Continental Crust (>25 km)
# ...                       ...                                           ...
# 1498    Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 1499    Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 1500    Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 1503    Basalt / Picro-Basalt     Subduction Zone / Oceanic Crust (< 15 km)
# 1504                 Rhyolite     Subduction Zone / Oceanic Crust (< 15 km)
#
# [871 rows x 12 columns]

# %%
lke = vlc['Last Known Eruption'].values

# %%
parsed_yrs = [parse(y).year for y in lke]

# %%
parsed_yrs
# Out:
# ['-8300',
#  '-4040',
#  '-3600',
#  '1282',
#  '-0104',
#  '1538',
#  '1944',
#  '1302',
#  '-8040',
#  '2016',
#  '1230',
#  '1890',
#  '2016',
#  '1867',
#  '1891',
#  '-1050',
#  '-0258',
#  '0140',
#  '1950',
#  '1888',
#  '-2080',
#  '-6880',
#  '1650',
#  '1855',
#  '1840',
#  '2050',
#  '-0750',
#  '-1900',
#  '-2000',
#  '-0778',
#  '-3000',
#  '2008',
#  '2013',
#  '2011',
#  '2008',
#  '2016',
#  '1861',
#  '2012',
#  '1915',
#  '2005',
#  '2009',
#  '1928',
#  '1978',
#  '1631',
#  '1820',
#  '1820',
#  '1900',
#  '-2050',
#  '1888',
#  '1921',
#  '-6550',
#  '1910',
#  '-5050',
#  '-7550',
#  '-6050',
#  '1770',
#  '1863',
#  '2013',
#  '1855',
#  '1910',
#  '-10450',
#  '1450',
#  '1250',
#  '1800',
#  '-2120',
#  '2015',
#  '2016',
#  '-8050',
#  '1957',
#  '1923',
#  '2000',
#  '-2000',
#  '-2950',
#  '0850',
#  '1222',
#  '1850',
#  '0640',
#  '1000',
#  '0650',
#  '1256',
#  '1810',
#  '0500',
#  '-1200',
#  '1937',
#  '1253',
#  '-5350',
#  '-2050',
#  '2007',
#  '-6050',
#  '2016',
#  '1995',
#  '1793',
#  '2016',
#  '2005',
#  '2004',
#  '0400',
#  '1350',
#  '-5060',
#  '1854',
#  '2016',
#  '1981',
#  '1180',
#  '0180',
#  '0260',
#  '2012',
#  '2007',
#  '2008',
#  '1360',
#  '2012',
#  '-4360',
#  '2006',
#  '2012',
#  '1932',
#  '1999',
#  '2015',
#  '1936',
#  '2014',
#  '1995',
#  '2006',
#  '1854',
#  '2001',
#  '1957',
#  '1979',
#  '1985',
#  '2008',
#  '2009',
#  '2003',
#  '1866',
#  '1911',
#  '1550',
#  '1660',
#  '1957',
#  '1972',
#  '1960',
#  '2016',
#  '2014',
#  '1993',
#  '2007',
#  '2016',
#  '1895',
#  '2008',
#  '2012',
#  '0950',
#  '1886',
#  '2016',
#  '1912',
#  '2014',
#  '-4946',
#  '1956',
#  '1935',
#  '1944',
#  '1350',
#  '-0350',
#  '1580',
#  '2016',
#  '-1050',
#  '1910',
#  '2007',
#  '1847',
#  '2012',
#  '1966',
#  '2011',
#  '2011',
#  '2016',
#  '2007',
#  '2004',
#  '1974',
#  '1881',
#  '2016',
#  '1996',
#  '1956',
#  '1903',
#  '-2900',
#  '2016',
#  '1839',
#  '2000',
#  '1937',
#  '1881',
#  '2016',
#  '1986',
#  '2015',
#  '1924',
#  '2007',
#  '2016',
#  '1921',
#  '2000',
#  '2009',
#  '1940',
#  '1933',
#  '2014',
#  '1939',
#  '1938',
#  '1957',
#  '2013',
#  '2002',
#  '1847',
#  '1984',
#  '1951',
#  '2014',
#  '2009',
#  '1971',
#  '1730',
#  '1797',
#  '2014',
#  '-0160',
#  '1885',
#  '2014',
#  '1952',
#  '2016',
#  '2016',
#  '1898',
#  '2015',
#  '1999',
#  '2000',
#  '1964',
#  '2016',
#  '1967',
#  '2015',
#  '1991',
#  '-8050',
#  '2001',
#  '1969',
#  '1969',
#  '1968',
#  '2014',
#  '2008',
#  '2003',
#  '2003',
#  '1993',
#  '2012',
#  '2013',
#  '2015',
#  '2015',
#  '1699',
#  '1892',
#  '1904',
#  '1968',
#  '1921',
#  '1988',
#  '1983',
#  '2005',
#  '2016',
#  '2015',
#  '1977',
#  '1880',
#  '2002',
#  '2016',
#  '1919',
#  '2004',
#  '2016',
#  '2016',
#  '2007',
#  '2016',
#  '1988',
#  '1897',
#  '1641',
#  '1290',
#  '0120',
#  '1882',
#  '1873',
#  '1886',
#  '1953',
#  '2016',
#  '1820',
#  '1939',
#  '2016',
#  '2014',
#  '-3500',
#  '1350',
#  '1977',
#  '-2050',
#  '1993',
#  '1860',
#  '1857',
#  '1978',
#  '1924',
#  '1854',
#  '1454',
#  '1933',
#  '1923',
#  '-0442',
#  '-5750',
#  '1853',
#  '1785',
#  '0648',
#  '1924',
#  '1968',
#  '1835',
#  '2016',
#  '1914',
#  '1190',
#  '2015',
#  '2013',
#  '0885',
#  '2016',
#  '-6200',
#  '2011',
#  '-0400',
#  '1996',
#  '2016',
#  '1996',
#  '0867',
#  '-6850',
#  '0650',
#  '1989',
#  '2015',
#  '1708',
#  '1200',
#  '2014',
#  '1659',
#  '-2050',
#  '1995',
#  '1839',
#  '1998',
#  '-0750',
#  '2015',
#  '1983',
#  '0550',
#  '1544',
#  '1952',
#  '-9540',
#  '-3050',
#  '-4570',
#  '1963',
#  '-3400',
#  '1888',
#  '1996',
#  '1977',
#  '1940',
#  '0837',
#  '1950',
#  '1974',
#  '1971',
#  '1919',
#  '-5350',
#  '1997',
#  '-2050',
#  '1863',
#  '0915',
#  '1550',
#  '1787',
#  '1990',
#  '-4550',
#  '0886',
#  '0838',
#  '2010',
#  '-4100',
#  '1606',
#  '1785',
#  '1970',
#  '1916',
#  '2002',
#  '2015',
#  '1984',
#  '1945',
#  '2012',
#  '1954',
#  '2010',
#  '1975',
#  '1974',
#  '1959',
#  '1967',
#  '2014',
#  '1989',
#  '1906',
#  '1917',
#  '2012',
#  '0870',
#  '1883',
#  '2010',
#  '2008',
#  '1995',
#  '2010',
#  '2015',
#  '1790',
#  '1874',
#  '2000',
#  '2001',
#  '-4900',
#  '-1050',
#  '1820',
#  '1981',
#  '-5830',
#  '2004',
#  '1739',
#  '1898',
#  '2008',
#  '1320',
#  '1080',
#  '1800',
#  '1936',
#  '1848',
#  '1880',
#  '1981',
#  '-7480',
#  '1932',
#  '2013',
#  '1951',
#  '1860',
#  '1999',
#  '1973',
#  '2016',
#  '1972',
#  '1914',
#  '1957',
#  '1825',
#  '1960',
#  '1884',
#  '1957',
#  '2009',
#  '1924',
#  '2016',
#  '2010',
#  '2014',
#  '1933',
#  '1952',
#  '1938',
#  '1854',
#  '1952',
#  '2016',
#  '2016',
#  '2016',
#  '1350',
#  '1690',
#  '-4050',
#  '0350',
#  '-6440',
#  '1901',
#  '1923',
#  '1907',
#  '-0300',
#  '2000',
#  '2010',
#  '1776',
#  '0300',
#  '-8050',
#  '-3550',
#  '2009',
#  '2001',
#  '2016',
#  '0390',
#  '1350',
#  '-0550',
#  '-0800',
#  '1996',
#  '2016',
#  '1952',
#  '-4450',
#  '-0550',
#  '0200',
#  '1550',
#  '1550',
#  '1923',
#  '-0550',
#  '0950',
#  '-0550',
#  '2013',
#  '2013',
#  '2016',
#  '2016',
#  '1890',
#  '2016',
#  '-5050',
#  '1500',
#  '-4550',
#  '1740',
#  '-5310',
#  '1600',
#  '-2240',
#  '-0800',
#  '-7050',
#  '1250',
#  '0850',
#  '-1060',
#  '-0550',
#  '-7550',
#  '-3550',
#  '-3450',
#  '-2050',
#  '-1550',
#  '-0220',
#  '-5180',
#  '-2980',
#  '0650',
#  '1951',
#  '',
#  '1776',
#  '-0520',
#  '0350',
#  '1903',
#  '-2990',
#  '1007',
#  '1990',
#  '1830',
#  '1987',
#  '1989',
#  '1914',
#  '1550',
#  '2012',
#  '-1600',
#  '1974',
#  '2008',
#  '-1150',
#  '1812',
#  '2007',
#  '1993',
#  '1997',
#  '1937',
#  '1828',
#  '2016',
#  '1929',
#  '1878',
#  '2008',
#  '1992',
#  '1995',
#  '1992',
#  '1992',
#  '1830',
#  '2015',
#  '-7600',
#  '1796',
#  '2016',
#  '-1890',
#  '1987',
#  '2013',
#  '-1900',
#  '1931',
#  '-0800',
#  '1998',
#  '1814',
#  '1977',
#  '1953',
#  '-0500',
#  '1974',
#  '1912',
#  '1912',
#  '-1790',
#  '1710',
#  '-3850',
#  '2006',
#  '2006',
#  '1876',
#  '2009',
#  '1992',
#  '1200',
#  '-1280',
#  '0300',
#  '-1050',
#  '2002',
#  '0847',
#  '-2220',
#  '0950',
#  '-7050',
#  '1800',
#  '1690',
#  '-5220',
#  '1550',
#  '-0410',
#  '-8060',
#  '1880',
#  '1700',
#  '1894',
#  '0950',
#  '2008',
#  '-5750',
#  '-6250',
#  '1866',
#  '0950',
#  '0680',
#  '2070',
#  '0480',
#  '0440',
#  '-5800',
#  '-2790',
#  '0690',
#  '-2850',
#  '-5610',
#  '-1250',
#  '1786',
#  '1060',
#  '1917',
#  '1790',
#  '1350',
#  '1380',
#  '1260',
#  '-4050',
#  '-5550',
#  '0210',
#  '-8400',
#  '-0130',
#  '-0300',
#  '-3250',
#  '-1350',
#  '1050',
#  '1290',
#  '-3250',
#  '-1170',
#  '-2200',
#  '1100',
#  '1075',
#  '-3490',
#  '-1180',
#  '1993',
#  '2015',
#  '1986',
#  '1996',
#  '-2260',
#  '1996',
#  '2016',
#  '1984',
#  '-2460',
#  '1801',
#  '1750',
#  '1985',
#  '1972',
#  '1970',
#  '-2050',
#  '1989',
#  '-2050',
#  '-2050',
#  '2003',
#  '2006',
#  '1996',
#  '1969',
#  '1990',
#  '1890',
#  '1915',
#  '1953',
#  '1994',
#  '1875',
#  '2016',
#  '1952',
#  '-3050',
#  '1270',
#  '-1350',
#  '0400',
#  '2016',
#  '-1170',
#  '-4470',
#  '-1200',
#  '1150',
#  '-3920',
#  '1846',
#  '1796',
#  '1982',
#  '1986',
#  '2016',
#  '1818',
#  '1853',
#  '1972',
#  '2016',
#  '2016',
#  '-0960',
#  '2005',
#  '1966',
#  '1917',
#  '1880',
#  '2016',
#  '1859',
#  '2016',
#  '2016',
#  '1999',
#  '1954',
#  '2016',
#  '-2050',
#  '1060',
#  '2016',
#  '2011',
#  '2014',
#  '1946',
#  '2010',
#  '2016',
#  '-6050',
#  '1994',
#  '2016',
#  '1550',
#  '-5390',
#  '1720',
#  '2016',
#  '-0850',
#  '1943',
#  '1180',
#  '2012',
#  '1977',
#  '1906',
#  '2014',
#  '-0930',
#  '1926',
#  '1936',
#  '-6650',
#  '-3740',
#  '0650',
#  '-5550',
#  '1786',
#  '2016',
#  '0290',
#  '2002',
#  '-0320',
#  '1773',
#  '1802',
#  '-2450',
#  '1895',
#  '2016',
#  '1280',
#  '0550',
#  '2016',
#  '2016',
#  '2009',
#  '1150',
#  '2015',
#  '1813',
#  '1993',
#  '2005',
#  '2008',
#  '1928',
#  '1991',
#  '1906',
#  '-4450',
#  '1490',
#  '-0700',
#  '2016',
#  '1985',
#  '2016',
#  '1600',
#  '1800',
#  '1802',
#  '-1320',
#  '-0320',
#  '0290',
#  '1960',
#  '1913',
#  '1995',
#  '1867',
#  '1960',
#  '1810',
#  '2016',
#  '-5250',
#  '1877',
#  '0750',
#  '-2300',
#  '1987',
#  '1960',
#  '1912',
#  '1917',
#  '2011',
#  '-6890',
#  '1933',
#  '1967',
#  '-2050',
#  '-4890',
#  '-5050',
#  '2016',
#  '1822',
#  '1869',
#  '2016',
#  '1980',
#  '-4000',
#  '1990',
#  '2009',
#  '1240',
#  '-5050',
#  '2016',
#  '1872',
#  '0560',
#  '1750',
#  '1937',
#  '1979',
#  '2012',
#  '-0230',
#  '1850',
#  '1869',
#  '-0190',
#  '2015',
#  '1090',
#  '0340',
#  '-0590',
#  '1920',
#  '1835',
#  '2011',
#  '-6650',
#  '-4920',
#  '0200',
#  '1710',
#  '1560',
#  '2011',
#  '1979',
#  '1979',
#  '1988',
#  '-1250',
#  '1908',
#  '1910',
#  '-5550',
#  '1820',
#  '1640',
#  '0250',
#  '0160',
#  '2013',
#  '1977',
#  '0920',
#  '1997',
#  '1270',
#  '1932',
#  '1766',
#  '1979',
#  '2015',
#  '0200',
#  '0960',
#  '1926',
#  '1340',
#  '1341',
#  '0150',
#  '-3500',
#  '-3350',
#  '0950',
#  '1973',
#  '2010',
#  '1918',
#  '1477',
#  '2000',
#  '2011',
#  '2015',
#  '1968',
#  '1961',
#  '-1200',
#  '1984',
#  '-0900',
#  '1868',
#  '1728',
#  '1755',
#  '1985',
#  '1999',
#  '1865',
#  '-0950',
#  '1958',
#  '1720',
#  '1907',
#  '-1950',
#  '2000',
#  '1720',
#  '1880',
#  '1652',
#  '1564',
#  '1630',
#  '1911',
#  '-4500',
#  '1971',
#  '2012',
#  '1909',
#  '2040',
#  '1824',
#  '2015',
#  '2002',
#  '1962',
#  '2004',
#  '-2050',
#  '1899',
#  '-1050',
#  '1892',
#  '2016',
#  '-8350',
#  '-5550',
#  '-0210',
#  '1970',
#  '1905',
#  '1975',
#  '2016',
#  '2007',
#  '2015',
#  '1911',
#  '2016',
#  '1962']

# %%
vlc['Last Known Eruption'] = parsed_yrs

# %%
vlc = vlc[vlc['Last Known Eruption'] != '']

# %%
vlc['Last Known Eruption'] = vlc['Last Known Eruption'].astype(int)

# %%
vlc['Last Known Eruption']
# Out:
# 0      -8300
# 1      -4040
# 3      -3600
# 4       1282
# 5       -104
#         ...
# 1498    2007
# 1499    2015
# 1500    1911
# 1503    2016
# 1504    1962
# Name: Last Known Eruption, Length: 870, dtype: int32

# %%
vlc = vlc[vlc['Last Known Eruption'] > 0]

# %%
vlc.shape
# Out:
# (696, 12)

# %%
vlc
# Out:
#       Number                 Name         Country  \
# 4     211001           Larderello           Italy
# 7     211010        Campi Flegrei           Italy
# 8     211020             Vesuvius           Italy
# 9     211030               Ischia           Italy
# 11    211040            Stromboli           Italy
# ...      ...                  ...             ...
# 1498  390081       Montagu Island  United Kingdom
# 1499  390090             Saunders  United Kingdom
# 1500  390100     Candlemas Island  United Kingdom
# 1503  390130           Zavodovski  United Kingdom
# 1504  390140  Protector Seamounts  United Kingdom
#
#                               Region                 Type  Activity Evidence  \
# 4     Mediterranean and Western Asia  Explosion crater(s)  Eruption Observed
# 7     Mediterranean and Western Asia              Caldera  Eruption Observed
# 8     Mediterranean and Western Asia        Stratovolcano  Eruption Observed
# 9     Mediterranean and Western Asia              Complex  Eruption Observed
# 11    Mediterranean and Western Asia        Stratovolcano  Eruption Observed
# ...                              ...                  ...                ...
# 1498                      Antarctica               Shield  Eruption Observed
# 1499                      Antarctica        Stratovolcano  Eruption Observed
# 1500                      Antarctica        Stratovolcano  Eruption Observed
# 1503                      Antarctica        Stratovolcano  Eruption Observed
# 1504                      Antarctica            Submarine  Eruption Observed
#
#       Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 4                    1282    43.250     10.870                 500
# 7                    1538    40.827     14.139                 458
# 8                    1944    40.821     14.426                1281
# 9                    1302    40.730     13.897                 789
# 11                   2016    38.789     15.213                 924
# ...                   ...       ...        ...                 ...
# 1498                 2007   -58.445    -26.374                1370
# 1499                 2015   -57.800    -26.483                 843
# 1500                 1911   -57.080    -26.670                 550
# 1503                 2016   -56.300    -27.570                 551
# 1504                 1962   -55.912    -28.167                 -55
#
#                             Dominant Rock Type  \
# 4                                      No Data
# 7                      Trachyte / Trachydacite
# 8           Phono-tephrite /  Tephri-phonolite
# 9                      Trachyte / Trachydacite
# 11    Trachyandesite / Basaltic Trachyandesite
# ...                                        ...
# 1498                     Basalt / Picro-Basalt
# 1499                     Basalt / Picro-Basalt
# 1500                     Basalt / Picro-Basalt
# 1503                     Basalt / Picro-Basalt
# 1504                                  Rhyolite
#
#                                   Tectonic Setting
# 4     Subduction Zone / Continental Crust (>25 km)
# 7     Subduction Zone / Continental Crust (>25 km)
# 8     Subduction Zone / Continental Crust (>25 km)
# 9     Subduction Zone / Continental Crust (>25 km)
# 11    Subduction Zone / Continental Crust (>25 km)
# ...                                            ...
# 1498     Subduction Zone / Oceanic Crust (< 15 km)
# 1499     Subduction Zone / Oceanic Crust (< 15 km)
# 1500     Subduction Zone / Oceanic Crust (< 15 km)
# 1503     Subduction Zone / Oceanic Crust (< 15 km)
# 1504     Subduction Zone / Oceanic Crust (< 15 km)
#
# [696 rows x 12 columns]

# %%
sns.histplot(vlc['Last Known Eruption']);

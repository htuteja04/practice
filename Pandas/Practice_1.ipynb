# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas have 2 basic data types, series & DataFrames. series can be considered a column & DataFrame a table
#
#
# - standard way of creating a series is using a list
# - standard way of creating a DataFrame is using a dictionary

# %%
roll_num = [221,222,223,224]
roll_series = pd.Series(roll_num, name='Roll numbers')
roll_series
# Out:
# 0    221
# 1    222
# 2    223
# 3    224
# Name: Roll numbers, dtype: int64

# %%
names = ['Himanshu', 'Jay', 'Ken', 'Ron']
name_series = pd.Series(names, name='Names')
name_series
# Out:
# 0    Himanshu
# 1         Jay
# 2         Ken
# 3         Ron
# Name: Names, dtype: object

# %% [markdown]
# creating DataFrames

# %%
student_df = pd.DataFrame({'Student Name':['Himanshu', 'Jay', 'Ken', 'Ron'], 'Roll number':[221,222,223,224]})
student_df
# Out:
#   Student Name  Roll number
# 0     Himanshu          221
# 1          Jay          222
# 2          Ken          223
# 3          Ron          224

# %%
student_df1 = pd.DataFrame({'Student Name':names, 'Roll number':roll_num})
student_df1
# Out:
#   Student Name  Roll number
# 0     Himanshu          221
# 1          Jay          222
# 2          Ken          223
# 3          Ron          224

# %% [markdown]
# importing csv files & creating DataFrames

# %%
pressing_df = pd.read_csv('datasets/Pressing.csv',index_col=0)
pressing_df
# Out:
#                  Press  Succ     %  Def 3rd  Mid 3rd  Att 3rd
# Squad
# Arsenal           1869   533  28.5      610      790      469
# Aston Villa       1855   558  30.1      584      807      464
# Brighton          2033   676  33.3      703      853      477
# Burnley           1783   474  26.6      539      847      397
# Chelsea           2245   696  31.0      742      975      528
# Crystal Palace    2324   653  28.1      928      963      433
# Everton           2250   668  29.7      907      928      415
# Fulham            1853   549  29.6      633      767      453
# Leeds United      2685   872  32.5      940     1148      597
# Leicester City    2293   719  31.4      852      929      512
# Liverpool         2074   704  33.9      527      847      700
# Manchester City   1696   518  30.5      427      765      504
# Manchester Utd    2077   633  30.5      643      912      522
# Newcastle Utd     2238   559  25.0      889      940      409
# ...

# %%
df_spo = pd.read_csv('datasets\Spotify.csv')

# %%
df_spo
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %% [markdown]
# Indexing, selecting & Assigning

# %%
df_spo.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
df_spo.energy
# Out:
# 0       0.834
# 1       0.897
# 2       0.496
# 3       0.913
# 4       0.928
#         ...
# 1995    0.734
# 1996    0.702
# 1997    0.678
# 1998    0.520
# 1999    0.762
# Name: energy, Length: 2000, dtype: float64

# %%
df_spo['genre'].unique()
# Out:
# array(['pop', 'rock, pop', 'pop, country', 'rock, metal',
#        'hip hop, pop, R&B', 'hip hop', 'pop, rock', 'pop, R&B',
#        'Dance/Electronic', 'pop, Dance/Electronic',
#        'rock, Folk/Acoustic, easy listening', 'metal', 'hip hop, pop',
#        'R&B', 'pop, latin', 'Folk/Acoustic, rock',
#        'pop, easy listening, Dance/Electronic', 'rock',
#        'rock, blues, latin', 'pop, rock, metal', 'rock, pop, metal',
#        'hip hop, R&B', 'pop, Folk/Acoustic', 'set()',
#        'hip hop, pop, latin', 'hip hop, Dance/Electronic',
#        'hip hop, pop, rock', 'World/Traditional, Folk/Acoustic',
#        'Folk/Acoustic, pop', 'rock, easy listening',
#        'World/Traditional, hip hop', 'hip hop, pop, R&B, latin',
#        'rock, blues', 'rock, R&B, Folk/Acoustic, pop', 'latin',
#        'pop, R&B, Dance/Electronic', 'World/Traditional, rock',
#        'pop, rock, Dance/Electronic', 'pop, easy listening, jazz',
# ...

# %%
df_spo['duration_ms'].max()
# Out:
# 484146

# %%
df_spo['duration_mins'] = df_spo['duration_ms']/60000

# %%
df_spo.query('duration_mins == duration_mins.max()')
# Out:
#                  artist     song  duration_ms  explicit  year  popularity  \
# 1381  Justin Timberlake  Mirrors       484146     False  2013          78
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 1381         0.574   0.512    5    -6.664     0       0.0503         0.234
#
#       instrumentalness  liveness  valence   tempo genre  duration_mins
# 1381               0.0    0.0946    0.512  76.899   pop         8.0691

# %%
df_spo[df_spo['artist']=='Rihanna'][:5]
# Out:
#       artist               song  duration_ms  explicit  year  popularity  \
# 503  Rihanna      Pon de Replay       246960     False  2005          77
# 605  Rihanna                SOS       238920     False  2006          73
# 648  Rihanna         Unfaithful       226973     False  2006          70
# 701  Rihanna           Umbrella       275986     False  2008          81
# 726  Rihanna  Shut Up And Drive       212280     False  2008          69
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 503         0.779   0.640    7    -8.415     1       0.1590      0.000155
# 605         0.677   0.671    7    -4.905     1       0.0361      0.004000
# 648         0.588   0.391    0    -8.607     0       0.0334      0.839000
# 701         0.583   0.829    1    -4.603     1       0.1340      0.008640
# 726         0.735   0.826    1    -4.902     1       0.0349      0.001010
#
#      instrumentalness  liveness  valence    tempo              genre  \
# ...

# %% [markdown]
#     -iloc is index based operator
#     -loc is label based
#     -both take arguments as row first, column second
#
# eg. df.iloc[row_index range, column_index range]

# %%
df_spo.iloc[:10, :10] # upto 10th row & 10th column
# Out:
#             artist                    song  duration_ms  explicit  year  \
# 0   Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1        blink-182    All The Small Things       167066     False  1999
# 2       Faith Hill                 Breathe       250546     False  1999
# 3         Bon Jovi            It's My Life       224493     False  2000
# 4           *NSYNC             Bye Bye Bye       200560     False  2000
# 5            Sisqo              Thong Song       253733      True  1999
# 6           Eminem     The Real Slim Shady       284200      True  2000
# 7  Robbie Williams                 Rock DJ       258560     False  2000
# 8  Destiny's Child             Say My Name       271333     False  1999
# 9            Modjo  Lady - Hear Me Tonight       307153     False  2001
#
#    popularity  danceability  energy  key  loudness
# 0          77         0.751   0.834    1    -5.444
# 1          79         0.434   0.897    0    -4.918
# ...

# %%
df_spo.iloc[:5, :] #upto 5th row, all columns
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre  \
# ...

# %%
df_spo.iloc[:, :3] #all rows, upto 3 columns
# Out:
#               artist                                    song  duration_ms
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
# [2000 rows x 3 columns]

# %%
df_spo.iloc[[1,3,5], [1,2,4,6]] #custom rows & columns
# Out:
#                    song  duration_ms  year  danceability
# 1  All The Small Things       167066  1999         0.434
# 3          It's My Life       224493  2000         0.551
# 5            Thong Song       253733  1999         0.706

# %%
df_spo.iloc[-5:, -5:] #last 5 columns & last 5 rows
# Out:
#       liveness  valence    tempo             genre  duration_mins
# 1995    0.1060    0.952  137.958               pop       3.017100
# 1996    0.1050    0.564  169.994               pop       2.973767
# 1997    0.2740    0.811   97.984  hip hop, country       3.343217
# 1998    0.2220    0.347  102.998               pop       2.850483
# 1999    0.0863    0.553  120.042           hip hop       3.588000

# %% [markdown]
# loc is strictly column name based

# %%
df_spo.loc[:, 'tempo'] #all rows, specific column
# Out:
# 0        95.053
# 1       148.726
# 2       136.859
# 3       119.992
# 4       172.656
#          ...
# 1995    137.958
# 1996    169.994
# 1997     97.984
# 1998    102.998
# 1999    120.042
# Name: tempo, Length: 2000, dtype: float64

# %%
df_spo.loc[:10, ['artist', 'duration_mins']] #10 rows, specific columns
# Out:
#              artist  duration_mins
# 0    Britney Spears       3.519333
# 1         blink-182       2.784433
# 2        Faith Hill       4.175767
# 3          Bon Jovi       3.741550
# 4            *NSYNC       3.342667
# 5             Sisqo       4.228883
# 6            Eminem       4.736667
# 7   Robbie Williams       4.309333
# 8   Destiny's Child       4.522217
# 9             Modjo       5.119217
# 10  Gigi D'Agostino       3.979317

# %%
df_spo.loc[(df_spo['artist']=='Rihanna') & (df_spo['year'] == 2008)]
# Out:
#       artist                  song  duration_ms  explicit  year  popularity  \
# 701  Rihanna              Umbrella       275986     False  2008          81
# 726  Rihanna     Shut Up And Drive       212280     False  2008          69
# 802  Rihanna            Take A Bow       229413     False  2008          74
# 811  Rihanna             Disturbia       238626     False  2008          76
# 819  Rihanna  Don't Stop The Music       267080     False  2008          77
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 701         0.583   0.829    1    -4.603     1       0.1340       0.00864
# 726         0.735   0.826    1    -4.902     1       0.0349       0.00101
# 802         0.697   0.467    9    -7.536     1       0.0715       0.24800
# 811         0.707   0.813   11    -4.515     0       0.0571       0.08630
# 819         0.835   0.669    6    -5.582     0       0.0643       0.03360
#
# ...

# %%
df_spo.loc[(df_spo['genre'].isin(['rock', 'pop']))]
# Out:
#                    artist                                              song  \
# 0          Britney Spears                            Oops!...I Did It Again
# 4                  *NSYNC                                       Bye Bye Bye
# 10        Gigi D'Agostino                                  L'Amour Toujours
# 11              Eiffel 65  Move Your Body - Gabry Ponte Original Radio Edit
# 12           Bomfunk MC's                                        Freestyler
# ...                   ...                                               ...
# 1988  Panic! At The Disco                                        High Hopes
# 1990            Sam Smith                                 How Do You Sleep?
# 1995       Jonas Brothers                                            Sucker
# 1996         Taylor Swift                                      Cruel Summer
# 1998            Sam Smith            Dancing With A Stranger (with Normani)
#
# ...

# %%
df_spo.artist
# Out:
# 0       Britney Spears
# 1            blink-182
# 2           Faith Hill
# 3             Bon Jovi
# 4               *NSYNC
#              ...
# 1995    Jonas Brothers
# 1996      Taylor Swift
# 1997      Blanco Brown
# 1998         Sam Smith
# 1999       Post Malone
# Name: artist, Length: 2000, dtype: object

# %%
df_spo.artist.map(lambda p:p.upper())
# Out:
# 0       BRITNEY SPEARS
# 1            BLINK-182
# 2           FAITH HILL
# 3             BON JOVI
# 4               *NSYNC
#              ...
# 1995    JONAS BROTHERS
# 1996      TAYLOR SWIFT
# 1997      BLANCO BROWN
# 1998         SAM SMITH
# 1999       POST MALONE
# Name: artist, Length: 2000, dtype: object

# %% [markdown]
# map function applies one operation to numerous values
#
#
# lambda is a shortened way to use a function

# %%
df_spo.genre.map(lambda p:p.upper())
# Out:
# 0                    POP
# 1              ROCK, POP
# 2           POP, COUNTRY
# 3            ROCK, METAL
# 4                    POP
#               ...
# 1995                 POP
# 1996                 POP
# 1997    HIP HOP, COUNTRY
# 1998                 POP
# 1999             HIP HOP
# Name: genre, Length: 2000, dtype: object

# %% [markdown]
# map returns a series
#
#
# syntax: df.column.map(function) function will applied on each value of that column

# %%
df_spo.genre.value_counts()[:10]
# Out:
# pop                               428
# hip hop, pop                      277
# hip hop, pop, R&B                 244
# pop, Dance/Electronic             221
# pop, R&B                          178
# hip hop                           124
# hip hop, pop, Dance/Electronic     78
# rock                               58
# rock, pop                          43
# Dance/Electronic                   41
# Name: genre, dtype: int64

# %%
df_spo['artist'].value_counts()
# Out:
# Rihanna           25
# Drake             23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
#                   ..
# Sidney Samson      1
# Cam’ron            1
# Elvis Presley      1
# Lucenzo            1
# Blanco Brown       1
# Name: artist, Length: 835, dtype: int64

# %%
df_spo.loc[(df_spo.artist == 'Calvin Harris')]
# Out:
#              artist                                               song  \
# 745   Calvin Harris                             Acceptable in the 80's
# 968   Calvin Harris                         I'm Not Alone - Radio Edit
# 1169  Calvin Harris                  Bounce (feat. Kelis) - Radio Edit
# 1244  Calvin Harris                         Feel So Close - Radio Edit
# 1251  Calvin Harris                             Let's Go (feat. Ne-Yo)
# 1277  Calvin Harris               We'll Be Coming Back (feat. Example)
# 1347  Calvin Harris      Drinking from the Bottle (feat. Tinie Tempah)
# 1353  Calvin Harris            I Need Your Love (feat. Ellie Goulding)
# 1359  Calvin Harris               Sweet Nothing (feat. Florence Welch)
# 1369  Calvin Harris              Thinking About You (feat. Ayah Marar)
# 1423  Calvin Harris                        Under Control (feat. Hurts)
# 1429  Calvin Harris                          Blame (feat. John Newman)
# ...

# %%
df_spo.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667437     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512435     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
df_spo.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre  \
# ...

# %%
df_spo.tail()
# Out:
#               artist                                    song  duration_ms  \
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 1995     False  2019          79         0.842   0.734    1    -5.065     0
# 1996     False  2019          78         0.552   0.702    9    -5.707     1
# 1997     False  2019          69         0.847   0.678    9    -8.635     1
# 1998     False  2019          75         0.741   0.520    8    -7.513     1
# 1999     False  2019          85         0.695   0.762    0    -3.497     1
#
# ...

# %%
longest = df_spo.duration_ms.idxmax() #index at which duration_ms has highest value

# %%
df_spo.loc[longest, 'song']
# Out:
# 'Mirrors'

# %% [markdown]
# idxmax returns the index of highest value in a series

# %%
shortest = df_spo.duration_ms.idxmin()

# %%
df_spo.loc[shortest, 'song']
# Out:
# 'Old Town Road'

# %%
dfw = pd.read_csv('Datasets\Winemag1.csv',index_col=0)

# %%
dfw.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
dfw.description
# Out:
# 0         This tremendous 100% varietal wine hails from ...
# 1         Ripe aromas of fig, blackberry and cassis are ...
# 2         Mac Watson honors the memory of a wine once ma...
# 3         This spent 20 months in 30% new French oak, an...
# 4         This is the top wine from La Bégude, named aft...
#                                 ...
# 150925    Many people feel Fiano represents southern Ita...
# 150926    Offers an intriguing nose with ginger, lime an...
# 150927    This classic example comes from a cru vineyard...
# 150928    A perfect salmon shade, with scents of peaches...
# 150929    More Pinot Grigios should taste like this. A r...
# Name: description, Length: 150930, dtype: object

# %%
fruity = dfw.description.map(lambda p: 'fruity' in p).sum()

# %%
tropical = dfw.description.map(lambda p: 'tropical' in p).sum()

# %%
descriptor_counts = pd.Series([fruity, tropical])
descriptor_counts
# Out:
# 0    8669
# 1    4135
# dtype: int64

# %%
dfw.points
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
dfw.points.apply(np.sqrt) #apply is equivalent to map
# Out:
# 0         9.797959
# 1         9.797959
# 2         9.797959
# 3         9.797959
# 4         9.746794
#             ...
# 150925    9.539392
# 150926    9.539392
# 150927    9.539392
# 150928    9.486833
# 150929    9.486833
# Name: points, Length: 150930, dtype: float64

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.apply(np.sum, axis=1) #columnwise addition
# Out:
# 0     6
# 1    15
# 2    24
# dtype: int64

# %%
df.apply(np.sum, axis=0) #row-wise addition
# Out:
# A    12
# B    15
# C    18
# dtype: int64

# %% [markdown]
# axis=0 for rows
#
# axis=1 for cols

# %%
df.apply(lambda p:(p*10).sum(),axis=1)
# Out:
# 0     60
# 1    150
# 2    240
# dtype: int64

# %%
df.apply(lambda p:(p*10).sum(),axis=0)
# Out:
# A    120
# B    150
# C    180
# dtype: int64

# %%
dfw.points
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
r_mean = dfw.points.mean()
def adjust(r):
    r.points = r.points - r_mean
    return r

dfw.apply(adjust,axis=1).head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation    points  price        province  \
# 0                     Martha's Vineyard  8.111582  235.0      California
# 1  Carodorum Selección Especial Reserva  8.111582  110.0  Northern Spain
# 2         Special Selected Late Harvest  8.111582   90.0      California
# 3                               Reserve  8.111582   65.0          Oregon
# 4                            La Brûlade  7.111582   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
dfw.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %%
dfw.groupby('price').price.count()
# Out:
# price
# 4.0         18
# 5.0         87
# 6.0        317
# 7.0        755
# 8.0       1633
#           ...
# 1300.0       1
# 1400.0       3
# 1900.0       1
# 2013.0       1
# 2300.0       1
# Name: price, Length: 357, dtype: int64

# %%
dir(dfw.groupby('country'))
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_agg_py_fallback',
#  '_aggregate_frame',
#  '_aggregate_item_by_item',
#  '_aggregate_with_numba',
#  '_apply_allowlist',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_ascending_count',
#  '_bool_agg',
#  '_can_use_transform_fast',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
# ...

# %%
dfw.groupby('country').points.max()[:8]
# Out:
# country
# Albania                    88
# Argentina                  97
# Australia                 100
# Austria                    98
# Bosnia and Herzegovina     88
# Brazil                     88
# Bulgaria                   90
# Canada                     93
# Name: points, dtype: int64

# %%
dfw.groupby('country').points.min()[:8]
# Out:
# country
# Albania                   88
# Argentina                 80
# Australia                 80
# Austria                   81
# Bosnia and Herzegovina    83
# Brazil                    81
# Bulgaria                  80
# Canada                    82
# Name: points, dtype: int64

# %%
dfw.groupby('country').points.mean()[:8]
# Out:
# country
# Albania                   88.000000
# Argentina                 85.996093
# Australia                 87.892475
# Austria                   89.276742
# Bosnia and Herzegovina    84.750000
# Brazil                    83.240000
# Bulgaria                  85.467532
# Canada                    88.239796
# Name: points, dtype: float64

# %%
dfw.groupby('country').price.mean()[:8]
# Out:
# country
# Albania                   20.000000
# Argentina                 20.794881
# Australia                 31.258480
# Austria                   31.192106
# Bosnia and Herzegovina    12.750000
# Brazil                    19.920000
# Bulgaria                  11.545455
# Canada                    34.628866
# Name: price, dtype: float64

# %%
dfw.loc[(dfw.country=='Egypt')]
# Out:
#        country                                        description  \
# 118982   Egypt  Ripe pear, apple and tropical fruit in the nos...
# 119008   Egypt  This fresh, approachable Chenin starts with br...
# 119894   Egypt  The character of this feminine, aromatic Viogn...
#
#                   designation  points  price province region_1 region_2  \
# 118982  Caspar Blanc de Noirs      84    NaN    Egypt      NaN      NaN
# 119008                 Caspar      84    NaN    Egypt      NaN      NaN
# 119894                    NaN      83    NaN    Egypt      NaN      NaN
#
#              variety            winery
# 118982      Grenache  Sahara Vineyards
# 119008  Chenin Blanc  Sahara Vineyards
# 119894      Viognier  Sahara Vineyards

# %%
dfw.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
dfw.groupby('country').points.agg(['min', 'max', 'mean'])[:8]
# Out:
#                         min  max       mean
# country
# Albania                  88   88  88.000000
# Argentina                80   97  85.996093
# Australia                80  100  87.892475
# Austria                  81   98  89.276742
# Bosnia and Herzegovina   83   88  84.750000
# Brazil                   81   88  83.240000
# Bulgaria                 80   90  85.467532
# Canada                   82   93  88.239796

# %%
dfw.groupby('country').price.agg(['min', 'max', 'mean'])[:10]
# Out:
#                          min     max       mean
# country
# Albania                 20.0    20.0  20.000000
# Argentina                4.0   250.0  20.794881
# Australia                5.0   850.0  31.258480
# Austria                  8.0  1100.0  31.192106
# Bosnia and Herzegovina  12.0    13.0  12.750000
# Brazil                  11.0    35.0  19.920000
# Bulgaria                 7.0    28.0  11.545455
# Canada                  12.0   145.0  34.628866
# Chile                    5.0   400.0  19.344780
# China                    7.0    27.0  20.333333

# %% [markdown]
# agg method allows us to display multiple aggregation metrics

# %%
dfw.country.sort_values()
# Out:
# 4864        Albania
# 4642        Albania
# 68798     Argentina
# 104858    Argentina
# 104854    Argentina
#             ...
# 1133            NaN
# 1440            NaN
# 68226           NaN
# 113016          NaN
# 135696          NaN
# Name: country, Length: 150930, dtype: object

# %%
country_df = dfw.groupby(['country']).description.agg([len])
country_df[:15]
# Out:
#                          len
# country
# Albania                    2
# Argentina               5631
# Australia               4957
# Austria                 3057
# Bosnia and Herzegovina     4
# Brazil                    25
# Bulgaria                  77
# Canada                   196
# Chile                   5816
# China                      3
# Croatia                   89
# Cyprus                    31
# Czech Republic             6
# Egypt                      3
# England                    9

# %%
country_df.sort_values(by='len')[:10]
# Out:
#              len
# country
# US-France      1
# Albania        2
# Tunisia        2
# Montenegro     2
# Japan          2
# Slovakia       3
# China          3
# Egypt          3
# Switzerland    4
# South Korea    4

# %%
animal_df = pd.DataFrame({'Name':['Tiger', 'Cheetah', 'Lion', 'Deer', 'Zebra', 'Wolf'], 'Speed':[50, 60, 40, 45, 35, 38]})
animal_df
# Out:
#       Name  Speed
# 0    Tiger     50
# 1  Cheetah     60
# 2     Lion     40
# 3     Deer     45
# 4    Zebra     35
# 5     Wolf     38

# %%
animal_df.sort_values(by='Speed')
# Out:
#       Name  Speed
# 4    Zebra     35
# 5     Wolf     38
# 2     Lion     40
# 3     Deer     45
# 0    Tiger     50
# 1  Cheetah     60

# %%
animal_df.sort_values(by='Name')
# Out:
#       Name  Speed
# 1  Cheetah     60
# 3     Deer     45
# 2     Lion     40
# 0    Tiger     50
# 5     Wolf     38
# 4    Zebra     35

# %%
uni = pd.read_csv('Datasets/Univ.csv')
uni
# Out:
#       Year    State                 Type  Length       Expense  Value
# 0     2013  Alabama              Private  4-year  Fees/Tuition  13983
# 1     2013  Alabama              Private  4-year    Room/Board   8503
# 2     2013  Alabama      Public In-State  2-year  Fees/Tuition   4048
# 3     2013  Alabama      Public In-State  4-year  Fees/Tuition   8073
# 4     2013  Alabama      Public In-State  4-year    Room/Board   8473
# ...    ...      ...                  ...     ...           ...    ...
# 3198  2020  Wyoming      Public In-State  4-year  Fees/Tuition   4747
# 3199  2020  Wyoming      Public In-State  4-year    Room/Board  10154
# 3200  2020  Wyoming  Public Out-of-State  2-year  Fees/Tuition  10101
# 3201  2020  Wyoming  Public Out-of-State  4-year  Fees/Tuition  14803
# 3202  2020  Wyoming  Public Out-of-State  4-year    Room/Board  10154
#
# [3203 rows x 6 columns]

# %%
uni.groupby('State').size()[:7]
# Out:
# State
# Alabama        64
# Alaska         58
# Arizona        64
# Arkansas       64
# California     64
# Colorado       64
# Connecticut    64
# dtype: int64

# %%
uni.groupby(['State','Length']).Value.size()[:20]
# Out:
# State                 Length
# Alabama               2-year    16
#                       4-year    48
# Alaska                2-year    10
#                       4-year    48
# Arizona               2-year    16
#                       4-year    48
# Arkansas              2-year    16
#                       4-year    48
# California            2-year    16
#                       4-year    48
# Colorado              2-year    16
#                       4-year    48
# Connecticut           2-year    16
#                       4-year    48
# Delaware              2-year     8
#                       4-year    48
# District of Columbia  4-year    32
# Florida               2-year    16
#                       4-year    48
# Georgia               2-year    16
# Name: Value, dtype: int64

# %%
uni.groupby('State')['Value'].max()
# Out:
# State
# Alabama                 26517
# Alaska                  26767
# Arizona                 27417
# Arkansas                23875
# California              37009
# Colorado                30773
# Connecticut             43242
# Delaware                31582
# District of Columbia    44134
# Florida                 27381
# Georgia                 29752
# Hawaii                  31774
# Idaho                   24845
# Illinois                35570
# Indiana                 34263
# Iowa                    35019
# Kansas                  24179
# Kentucky                27648
# Louisiana               39482
# Maine                   40353
# Maryland                44048
# Massachusetts           47980
# Michigan                37600
# Minnesota               34321
# Mississippi             19942
# Missouri                26377
# Montana                 31724
# Nebraska                25313
# Nevada                  26284
# New Hampshire           33446
# New Jersey              38652
# ...

# %%
uni.groupby('State')['Value'].agg([min, max, 'mean'])[:15]
# Out:
#                        min    max          mean
# State
# Alabama               4048  26517  11185.937500
# Alaska                3340  26767  11242.568966
# Arizona               1842  27417  11109.281250
# Arkansas              2633  23875  10054.250000
# California            1225  37009  14841.875000
# Colorado              3004  30773  13336.140625
# Connecticut           3596  43242  17131.734375
# Delaware              3215  31582  13559.357143
# District of Columbia  5251  44134  18309.093750
# Florida               2383  27381  11132.734375
# Georgia               2652  29752  12356.875000
# Hawaii                2484  31774  12328.140625
# Idaho                 2915  24845   8464.593750
# Illinois              3192  35570  14996.359375
# Indiana               3455  34263  13845.953125

# %%
uni
# Out:
#       Year    State                 Type  Length       Expense  Value
# 0     2013  Alabama              Private  4-year  Fees/Tuition  13983
# 1     2013  Alabama              Private  4-year    Room/Board   8503
# 2     2013  Alabama      Public In-State  2-year  Fees/Tuition   4048
# 3     2013  Alabama      Public In-State  4-year  Fees/Tuition   8073
# 4     2013  Alabama      Public In-State  4-year    Room/Board   8473
# ...    ...      ...                  ...     ...           ...    ...
# 3198  2020  Wyoming      Public In-State  4-year  Fees/Tuition   4747
# 3199  2020  Wyoming      Public In-State  4-year    Room/Board  10154
# 3200  2020  Wyoming  Public Out-of-State  2-year  Fees/Tuition  10101
# 3201  2020  Wyoming  Public Out-of-State  4-year  Fees/Tuition  14803
# 3202  2020  Wyoming  Public Out-of-State  4-year    Room/Board  10154
#
# [3203 rows x 6 columns]

# %%
d = uni.groupby(['State', 'Length']).size()

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
d.index
# Out:
# MultiIndex([(      'Alabama', '2-year'),
#             (      'Alabama', '4-year'),
#             (       'Alaska', '2-year'),
#             (       'Alaska', '4-year'),
#             (      'Arizona', '2-year'),
#             (      'Arizona', '4-year'),
#             (     'Arkansas', '2-year'),
#             (     'Arkansas', '4-year'),
#             (   'California', '2-year'),
#             (   'California', '4-year'),
#             ...
#             (     'Virginia', '2-year'),
#             (     'Virginia', '4-year'),
#             (   'Washington', '2-year'),
#             (   'Washington', '4-year'),
#             ('West Virginia', '2-year'),
#             ('West Virginia', '4-year'),
#             (    'Wisconsin', '2-year'),
#             (    'Wisconsin', '4-year'),
#             (      'Wyoming', '2-year'),
#             (      'Wyoming', '4-year')],
#            names=['State', 'Length'], length=101)

# %%
d1 = uni.groupby('State').size()

# %%
type(d1)
# Out:
# pandas.core.series.Series

# %%
d1.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State')

# %%
d2 = uni.groupby('State')['Value'].agg(['mean', max])

# %%
type(d2)
# Out:
# pandas.core.frame.DataFrame

# %%
d2.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State')

# %% [markdown]
# groupby returns a series
#
# groupby.column.agg returns a data frame
#
# both of them have index as the column on which data is grouped

# %%
dfw.isna().sum()
# Out:
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %%
dfw.isnull().sum()
# Out:
# country            5
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %% [markdown]
# isna / isnull for missing value counts

# %%
dfw['country'].fillna('Unknown',inplace=True)

# %%
dfw.isna().sum()
# Out:
# country            0
# description        0
# designation    45735
# points             0
# price          13695
# province           5
# region_1       25060
# region_2       89977
# variety            0
# winery             0
# dtype: int64

# %%
uni
# Out:
#       Year    State                 Type  Length       Expense  Value
# 0     2013  Alabama              Private  4-year  Fees/Tuition  13983
# 1     2013  Alabama              Private  4-year    Room/Board   8503
# 2     2013  Alabama      Public In-State  2-year  Fees/Tuition   4048
# 3     2013  Alabama      Public In-State  4-year  Fees/Tuition   8073
# 4     2013  Alabama      Public In-State  4-year    Room/Board   8473
# ...    ...      ...                  ...     ...           ...    ...
# 3198  2020  Wyoming      Public In-State  4-year  Fees/Tuition   4747
# 3199  2020  Wyoming      Public In-State  4-year    Room/Board  10154
# 3200  2020  Wyoming  Public Out-of-State  2-year  Fees/Tuition  10101
# 3201  2020  Wyoming  Public Out-of-State  4-year  Fees/Tuition  14803
# 3202  2020  Wyoming  Public Out-of-State  4-year    Room/Board  10154
#
# [3203 rows x 6 columns]

# %%
uni
# Out:
#       Year    State                 Type  Length       Expense  Value
# 0     2013  Alabama              Private  4-year  Fees/Tuition  13983
# 1     2013  Alabama              Private  4-year    Room/Board   8503
# 2     2013  Alabama      Public In-State  2-year  Fees/Tuition   4048
# 3     2013  Alabama      Public In-State  4-year  Fees/Tuition   8073
# 4     2013  Alabama      Public In-State  4-year    Room/Board   8473
# ...    ...      ...                  ...     ...           ...    ...
# 3198  2020  Wyoming      Public In-State  4-year  Fees/Tuition   4747
# 3199  2020  Wyoming      Public In-State  4-year    Room/Board  10154
# 3200  2020  Wyoming  Public Out-of-State  2-year  Fees/Tuition  10101
# 3201  2020  Wyoming  Public Out-of-State  4-year  Fees/Tuition  14803
# 3202  2020  Wyoming  Public Out-of-State  4-year    Room/Board  10154
#
# [3203 rows x 6 columns]

# %%
uni.State.value_counts()[:10]
# Out:
# Alabama           64
# Montana           64
# New Hampshire     64
# New Jersey        64
# New Mexico        64
# New York          64
# North Carolina    64
# North Dakota      64
# Ohio              64
# Oklahoma          64
# Name: State, dtype: int64

# %%
uni.groupby('State').State.count().sort_index()[:10]
# Out:
# State
# Alabama                 64
# Alaska                  58
# Arizona                 64
# Arkansas                64
# California              64
# Colorado                64
# Connecticut             64
# Delaware                56
# District of Columbia    32
# Florida                 64
# Name: State, dtype: int64

# %%
uni.State.value_counts().sort_index()[:10] #sort_index is used to sort the data as per the index, in this snippet the index is State values
# Out:
# Alabama                 64
# Alaska                  58
# Arizona                 64
# Arkansas                64
# California              64
# Colorado                64
# Connecticut             64
# Delaware                56
# District of Columbia    32
# Florida                 64
# Name: State, dtype: int64

# %%
animal_df
# Out:
#       Name  Speed
# 0    Tiger     50
# 1  Cheetah     60
# 2     Lion     40
# 3     Deer     45
# 4    Zebra     35
# 5     Wolf     38

# %% [markdown]
# if the data that is selected from a DataFrame is categorized by a particular column then comes out in the form of a series, the index is that particular column

# %%
uni
# Out:
#       Year    State                 Type  Length       Expense  Value
# 0     2013  Alabama              Private  4-year  Fees/Tuition  13983
# 1     2013  Alabama              Private  4-year    Room/Board   8503
# 2     2013  Alabama      Public In-State  2-year  Fees/Tuition   4048
# 3     2013  Alabama      Public In-State  4-year  Fees/Tuition   8073
# 4     2013  Alabama      Public In-State  4-year    Room/Board   8473
# ...    ...      ...                  ...     ...           ...    ...
# 3198  2020  Wyoming      Public In-State  4-year  Fees/Tuition   4747
# 3199  2020  Wyoming      Public In-State  4-year    Room/Board  10154
# 3200  2020  Wyoming  Public Out-of-State  2-year  Fees/Tuition  10101
# 3201  2020  Wyoming  Public Out-of-State  4-year  Fees/Tuition  14803
# 3202  2020  Wyoming  Public Out-of-State  4-year    Room/Board  10154
#
# [3203 rows x 6 columns]

# %%
s_count = uni.State.value_counts()

# %%
s_count[:8]
# Out:
# Alabama           64
# Montana           64
# New Hampshire     64
# New Jersey        64
# New Mexico        64
# New York          64
# North Carolina    64
# North Dakota      64
# Name: State, dtype: int64

# %%
type(s_count)
# Out:
# pandas.core.series.Series

# %%
s_count.index
# Out:
# Index(['Alabama', 'Montana', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Nebraska', 'Missouri',
#        'Illinois', 'California', 'Connecticut', 'Arkansas', 'Arizona',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Mississippi', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Colorado', 'Nevada',
#        'Alaska', 'Delaware', 'Wyoming', 'District of Columbia'],
#       dtype='object')

# %%
s_value = uni.groupby('State').Value.agg([min, max])

# %%
s_value[:10]
# Out:
#                        min    max
# State
# Alabama               4048  26517
# Alaska                3340  26767
# Arizona               1842  27417
# Arkansas              2633  23875
# California            1225  37009
# Colorado              3004  30773
# Connecticut           3596  43242
# Delaware              3215  31582
# District of Columbia  5251  44134
# Florida               2383  27381

# %%
s_value.index
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object', name='State')

# %%
ign = pd.read_csv('Datasets/ign.csv', index_col='Platform')

# %%
ign
# Out:
#                         Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast             6.882857           7.511111   6.281818  8.200000
# Game Boy Advance      6.373077           7.507692   6.057143  6.226316
# Game Boy Color        6.272727           8.166667   5.307692  4.500000
# GameCube              6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS          6.670833           7.481818   7.414286  6.614286
# Nintendo 64           6.649057           8.250000   7.000000  5.681250
# Nintendo DS           5.903608           7.240000   6.259804  6.320000
# Nintendo DSi          6.827027           8.500000   6.090909  7.500000
# PC                    6.805791           7.334746   7.136798  7.166667
# PlayStation           6.016406           7.933333   6.313725  6.553731
# PlayStation 2         6.467361           7.250000   6.315152  7.306349
# PlayStation 3         6.853819           7.306154   6.820988  7.710938
# ...

# %%
ign.loc['Xbox']
# Out:
# Action               6.819512
# Action, Adventure    7.479032
# Adventure            6.821429
# Fighting             7.029630
# Platformer           7.303448
# Puzzle               5.125000
# RPG                  8.277778
# Racing               7.021591
# Shooter              7.485417
# Simulation           7.155556
# Sports               7.884397
# Strategy             7.313333
# Name: Xbox, dtype: float64

# %% [markdown]
# loc on 1 value returns a series

# %%
ign.loc[['Xbox', 'PC']]
# Out:
#             Action  Action, Adventure  Adventure  Fighting  Platformer  \
# Platform
# Xbox      6.819512           7.479032   6.821429  7.029630    7.303448
# PC        6.805791           7.334746   7.136798  7.166667    7.410938
#
#             Puzzle       RPG    Racing   Shooter  Simulation    Sports  \
# Platform
# Xbox      5.125000  8.277778  7.021591  7.485417    7.155556  7.884397
# PC        6.924706  7.759930  7.032418  7.084878    7.104889  6.902424
#
#           Strategy
# Platform
# Xbox      7.313333
# PC        7.310207

# %% [markdown]
# loc on 1+ values returns a dataframe

# %%
type(ign.loc['PC'])
# Out:
# pandas.core.series.Series

# %%
ign.loc['PC'].index
# Out:
# Index(['Action', 'Action, Adventure', 'Adventure', 'Fighting', 'Platformer',
#        'Puzzle', 'RPG', 'Racing', 'Shooter', 'Simulation', 'Sports',
#        'Strategy'],
#       dtype='object')

# %%
ign.loc['PC'].values
# Out:
# array([6.80579065, 7.33474576, 7.13679775, 7.16666667, 7.4109375 ,
#        6.92470588, 7.75993031, 7.03241758, 7.08487805, 7.10488889,
#        6.90242424, 7.31020734])

# %%
ign.loc['PC'].idxmax()
# Out:
# 'RPG'

# %%
ign.loc['PC'].idxmin()
# Out:
# 'Action'

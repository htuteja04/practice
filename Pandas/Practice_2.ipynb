# %%
import pandas as pd
import numpy as np

# %%
cvd = pd.read_csv('Datasets/covid.csv')

# %%
cvd.shape
# Out:
# (151776, 67)

# %%
cvd.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
cvd.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.491540e+05  1.490300e+05        1.478790e+05  1.319890e+05
# mean   2.109497e+06  8.156646e+03        8.098208e+03  5.234021e+04
# std    1.250288e+07  4.594042e+04        4.427885e+04  2.753371e+05
# min    1.000000e+00 -7.434700e+04       -6.223000e+03  1.000000e+00
# 25%    1.542250e+03  1.000000e+00        5.714000e+00  6.700000e+01
# 50%    2.022100e+04  6.900000e+01        9.000000e+01  6.680000e+02
# 75%    2.531838e+05  9.120000e+02        9.633575e+02  6.413000e+03
# max    2.901468e+08  1.949468e+06        1.450119e+06  5.443578e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  132139.000000        132007.000000            148458.000000
# mean      170.900574           170.531834             23071.035195
# std       832.769116           813.988845             37617.190174
# min     -1918.000000          -232.143000                 0.001000
# ...

# %%
cvd.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
cvd.groupby('location')['life_expectancy'].agg(['mean'])
# Out:
#                     mean
# location
# Afghanistan        64.83
# Africa               NaN
# Albania            78.57
# Algeria            76.88
# Andorra            83.73
# ...                  ...
# Wallis and Futuna  79.94
# World              72.58
# Yemen              66.12
# Zambia             63.89
# Zimbabwe           61.49
#
# [238 rows x 1 columns]

# %%
cvd[['iso_code','gdp_per_capita']]
# Out:
#        iso_code  gdp_per_capita
# 0           AFG        1803.987
# 1           AFG        1803.987
# 2           AFG        1803.987
# 3           AFG        1803.987
# 4           AFG        1803.987
# ...         ...             ...
# 151771      ZWE        1899.775
# 151772      ZWE        1899.775
# 151773      ZWE        1899.775
# 151774      ZWE        1899.775
# 151775      ZWE        1899.775
#
# [151776 rows x 2 columns]

# %%
cvd.groupby('location')['gdp_per_capita'].agg(['mean'])
# Out:
#                         mean
# location
# Afghanistan         1803.987
# Africa                   NaN
# Albania            11803.431
# Algeria            13913.839
# Andorra                  NaN
# ...                      ...
# Wallis and Futuna        NaN
# World              15469.207
# Yemen               1479.147
# Zambia              3689.251
# Zimbabwe            1899.775
#
# [238 rows x 1 columns]

# %%
cvd.groupby('location')['population_density'].agg(['mean'])
# Out:
#                       mean
# location
# Afghanistan         54.422
# Africa                 NaN
# Albania            104.871
# Algeria             17.348
# Andorra            163.755
# ...                    ...
# Wallis and Futuna      NaN
# World               58.045
# Yemen               53.508
# Zambia              22.995
# Zimbabwe            42.729
#
# [238 rows x 1 columns]

# %%
cvd.groupby('location')['median_age'].agg(['mean'])
# Out:
#                    mean
# location
# Afghanistan        18.6
# Africa              NaN
# Albania            38.0
# Algeria            29.1
# Andorra             NaN
# ...                 ...
# Wallis and Futuna   NaN
# World              30.9
# Yemen              20.3
# Zambia             17.7
# Zimbabwe           19.6
#
# [238 rows x 1 columns]

# %%
Africa_df = cvd.loc[(cvd.continent == 'Africa')]

# %%
Africa_df.shape
# Out:
# (36007, 67)

# %%
Africa_df.isna().sum()[:15]
# Out:
# iso_code                             0
# continent                            0
# location                             0
# date                                 0
# total_cases                         88
# new_cases                          142
# new_cases_smoothed                 416
# total_deaths                      2455
# new_deaths                        2466
# new_deaths_smoothed               2481
# total_cases_per_million             88
# new_cases_per_million              142
# new_cases_smoothed_per_million     416
# total_deaths_per_million          2455
# new_deaths_per_million            2466
# dtype: int64

# %%
Africa_df.isna().sum()[15:30]
# Out:
# new_deaths_smoothed_per_million        2481
# reproduction_rate                      3195
# icu_patients                          35537
# icu_patients_per_million              35537
# hosp_patients                         36007
# hosp_patients_per_million             36007
# weekly_icu_admissions                 36007
# weekly_icu_admissions_per_million     36007
# weekly_hosp_admissions                35920
# weekly_hosp_admissions_per_million    35920
# new_tests                             26237
# total_tests                           26535
# total_tests_per_thousand              26535
# new_tests_per_thousand                26237
# new_tests_smoothed                    23322
# dtype: int64

# %%
Africa_df.isna().sum()[30:45]
# Out:
# new_tests_smoothed_per_thousand          23322
# positive_rate                            23703
# tests_per_case                           23796
# tests_units                              22082
# total_vaccinations                       32084
# people_vaccinated                        32310
# people_fully_vaccinated                  33154
# total_boosters                           35945
# new_vaccinations                         33964
# new_vaccinations_smoothed                21663
# total_vaccinations_per_hundred           32084
# people_vaccinated_per_hundred            32310
# people_fully_vaccinated_per_hundred      33154
# total_boosters_per_hundred               35945
# new_vaccinations_smoothed_per_million    21663
# dtype: int64

# %%
Africa_df.isna().sum()[45:67]
# Out:
# new_people_vaccinated_smoothed                21723
# new_people_vaccinated_smoothed_per_hundred    21723
# stringency_index                               3910
# population                                        0
# population_density                             1121
# median_age                                      483
# aged_65_older                                   483
# aged_70_older                                   483
# gdp_per_capita                                 1141
# extreme_poverty                                9017
# cardiovasc_death_rate                           483
# diabetes_prevalence                             483
# female_smokers                                12295
# male_smokers                                  12295
# handwashing_facilities                         7069
# hospital_beds_per_thousand                     9637
# life_expectancy                                   0
# human_development_index                        1141
# ...

# %% [markdown]
# all columns having missing values in Africa dataframe

# %%
Asia_df = cvd.loc[(cvd.continent == 'Asia')]

# %%
Europe_df = cvd.loc[(cvd.continent == 'Europe')]

# %%
Asia_df.groupby('location')['life_expectancy'].mean()[:10]
# Out:
# location
# Afghanistan    64.83
# Armenia        75.09
# Azerbaijan     73.00
# Bahrain        77.29
# Bangladesh     72.59
# Bhutan         71.78
# Brunei         75.86
# Cambodia       69.82
# China          76.91
# Georgia        73.77
# Name: life_expectancy, dtype: float64

# %%
cvd['location'].unique()[:10]
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia'],
#       dtype=object)

# %%
cvd.continent.unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
nan_cont = cvd.loc[(cvd.continent!='Asia') & (cvd.continent!='Europe') & (cvd.continent!='Africa') & (cvd.continent!='North America') & (cvd.continent!='South America') & (cvd.continent!='Oceania')]

# %%
nan_cont['continent'].unique()
# Out:
# array([nan], dtype=object)

# %%
nan_cont.isna().sum()
# Out:
# iso_code                                      0
# continent                                  9150
# location                                      0
# date                                          0
# total_cases                                   7
#                                            ...
# human_development_index                    8438
# excess_mortality_cumulative_absolute       9150
# excess_mortality_cumulative                9150
# excess_mortality                           9150
# excess_mortality_cumulative_per_million    9150
# Length: 67, dtype: int64

# %%
nan_cont.size #size always gives total value count
# Out:
# 613050

# %%
nan_cont['continent'].isna().sum()
# Out:
# 9150

# %%
Asia_df.shape
# Out:
# (33198, 67)

# %%
Europe_df.shape
# Out:
# (33918, 67)

# %%
Africa_df.shape
# Out:
# (36007, 67)

# %%
Asia_df.isna().sum()[Asia_df.isna().sum() > 30000]
# Out:
# icu_patients                               32044
# icu_patients_per_million                   32044
# hosp_patients                              31876
# hosp_patients_per_million                  31876
# weekly_icu_admissions                      32538
# weekly_icu_admissions_per_million          32538
# weekly_hosp_admissions                     32532
# weekly_hosp_admissions_per_million         32532
# total_boosters                             31608
# total_boosters_per_hundred                 31608
# excess_mortality_cumulative_absolute       32493
# excess_mortality_cumulative                32493
# excess_mortality                           32493
# excess_mortality_cumulative_per_million    32493
# dtype: int64

# %%
Africa_df.isna().sum()[Africa_df.isna().sum() > 30000]
# Out:
# icu_patients                               35537
# icu_patients_per_million                   35537
# hosp_patients                              36007
# hosp_patients_per_million                  36007
# weekly_icu_admissions                      36007
# weekly_icu_admissions_per_million          36007
# weekly_hosp_admissions                     35920
# weekly_hosp_admissions_per_million         35920
# total_vaccinations                         32084
# people_vaccinated                          32310
# people_fully_vaccinated                    33154
# total_boosters                             35945
# new_vaccinations                           33964
# total_vaccinations_per_hundred             32084
# people_vaccinated_per_hundred              32310
# people_fully_vaccinated_per_hundred        33154
# total_boosters_per_hundred                 35945
# excess_mortality_cumulative_absolute       35846
# excess_mortality_cumulative                35846
# ...

# %%
Europe_df.isna().sum()[Europe_df.isna().sum() > 30000]
# Out:
# weekly_icu_admissions                      30303
# weekly_icu_admissions_per_million          30303
# handwashing_facilities                     31906
# excess_mortality_cumulative_absolute       30765
# excess_mortality_cumulative                30765
# excess_mortality                           30765
# excess_mortality_cumulative_per_million    30765
# dtype: int64

# %% [markdown]
# all columns having tons of missing values in each of the three dataframes we derived

# %%
asm_cols = [col for col in Asia_df.columns if Asia_df[col].isna().sum() > 25000]

# %%
asm_cols
# Out:
# ['icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
eum_cols = [col for col in Europe_df.columns if Europe_df[col].isna().sum() > 25000]

# %%
eum_cols
# Out:
# ['weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'total_boosters',
#  'total_boosters_per_hundred',
#  'handwashing_facilities',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
afm_cols = [col for col in Africa_df.columns if Africa_df[col].isna().sum() > 25000]

# %%
afm_cols
# Out:
# ['icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
#  'total_vaccinations_per_hundred',
#  'people_vaccinated_per_hundred',
#  'people_fully_vaccinated_per_hundred',
#  'total_boosters_per_hundred',
#  'excess_mortality_cumulative_absolute',
#  'excess_mortality_cumulative',
#  'excess_mortality',
#  'excess_mortality_cumulative_per_million']

# %%
Asia_df.shape
# Out:
# (33198, 67)

# %%
Asia_df_new = Asia_df.drop(Asia_df[asm_cols], axis=1)

# %%
Asia_df_new.shape
# Out:
# (33198, 50)

# %%
Europe_df_new = Europe_df.drop(Europe_df[eum_cols], axis=1)

# %%
Africa_df_new = Africa_df.drop(Africa_df[afm_cols], axis=1)

# %%
Asia_df.isna().sum()[:10]
# Out:
# iso_code                  0
# continent                 0
# location                  0
# date                      0
# total_cases             532
# new_cases               545
# new_cases_smoothed      785
# total_deaths           4284
# new_deaths             4290
# new_deaths_smoothed    4306
# dtype: int64

# %%
Asia_df_new.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
Asia_df_new.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'new_tests',
#        'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
# ...

# %%
Asia_df_new.groupby('location')[['population', 'median_age', 'life_expectancy', 'gdp_per_capita', 'human_development_index']].agg('mean')
# Out:
#                         population  median_age  life_expectancy  \
# location
# Afghanistan           3.983543e+07        18.6            64.83
# Armenia               2.968128e+06        35.7            75.09
# Azerbaijan            1.022334e+07        32.4            73.00
# Bahrain               1.748295e+06        32.4            77.29
# Bangladesh            1.663035e+08        27.5            72.59
# Bhutan                7.799000e+05        28.6            71.78
# Brunei                4.415320e+05        32.4            75.86
# Cambodia              1.694645e+07        25.6            69.82
# China                 1.444216e+09        38.7            76.91
# Georgia               3.979773e+06        38.7            73.77
# Hong Kong             7.552800e+06        44.8            84.86
# India                 1.393409e+09        28.2            69.66
# Indonesia             2.763618e+08        29.3            71.72
# ...
